# %% [markdown]
# For the project, we will need various data about each song. That is: lyrics, some measure of popularity, genre, artist, and release date. Unfortunately, this information is not all available from the same source. We will be collecting data from Genius (a website for song analysis which houses genre and lyrics) and Spotify (A major streaming platform which tracks the total plays and current popularity of a track). This means that in their raw form, the data we receive will not be properly associated by song. We will have to correctly identify which songs correspond across the platforms, and then associate the relavent data into our database. We will have to be carefull to minimize error which may arise from this process, as that will significantly effect our final results.

# %% [markdown]
# First, lets take a look at the Genius API. We have to set up an authenticated account with Genius, so that it will respond to our API calls. We must identify our application and its purpose, and we will then be given a client_id and a client_secret which will allow us to make requests to the server.

# %% [markdown]
# For this, we will need an email an password. I didn't want to use mine, and it makes sense for everyone on the project to have access to the email should they require it when working on the API; thus, I made a new email for project purposes only.
#
# Email: popularity.by.lyrics.analysis@gmail.com
#
# Password: 2020uofudatascience

# %% [markdown]
# After creating the Genius account and registering a new API Client App, we have our ID and secret:
#
# Client ID: f6xD9D1KtMiCZij5I-71axaKAN7G6NsuAtPcXzVLXenKdAyxZvmy9pMFBAvnP3j6
# Client Secret: l8ducnbdIpED0rQNKpADr1M5x4_Q4qTuPvXQ7tC5X1p9D-vkiX2uqdQ-oGs9J48jr_sbueHofnB4thJigUrsZA
#
# (Later, lets place this into a file which we access 'credientials.py')

# %% [markdown]
# Now that we have these, we need to perform an OAuth authentication process with the Genius API. This can be handled by a python package called rauth. The following cell installs rauth and imports it into the notebook.

# %%
# %conda install rauth
from rauth import OAuth2Service
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - rauth
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
#Create a variable to house the Genius authentication
genius = OAuth2Service(
    client_id = 'f6xD9D1KtMiCZij5I-71axaKAN7G6NsuAtPcXzVLXenKdAyxZvmy9pMFBAvnP3j6',
    client_secret = 'l8ducnbdIpED0rQNKpADr1M5x4_Q4qTuPvXQ7tC5X1p9D-vkiX2uqdQ-oGs9J48jr_sbueHofnB4thJigUrsZA',
    name = 'genius',
    authorize_url = 'https://api.genius.com/oauth/authorize',
    access_token_url = 'https://api.genius.com/oauth/token',
    base_url = 'https://api.genius.com/')

#Create a new session
access_token = 'qIcPSKG-IpOYMR0j-Y2NcuHVuGsbGHO3osa4b7BEJuFaBbZgDn26EKjl_whhxSjO'
session = genius.get_session(access_token)

#Make a simple request to the API
response = session.get('songs/378195')

#Print the first 300 characters of the binary stream converted to string by utf-8 encoding
response.content.decode('utf-8')[:300]
# Out:
# '{"meta":{"status":200},"response":{"song":{"annotation_count":33,"api_path":"/songs/378195","apple_music_id":"882945383","apple_music_player_url":"https://genius.com/songs/378195/apple_music_player","description":{"dom":{"tag":"root","children":[{"tag":"p","children":["“Chandelier” was released as t'

# %% [markdown]
# Looks like the song which we grabed was Chandelier by Sia. Lets explore the structure of this object ot find the data which we are looking for. The response we recieved is a JSON object, so we will need to convert it from the binary stream to a string, and then finally to a proper JSON object which we can use indexing on. To do this, we will import the json library.

# %%
import json

json_object = json.loads(response.content.decode('utf-8'))
json_object
# Out:
# {'meta': {'status': 200},
#  'response': {'song': {'annotation_count': 33,
#    'api_path': '/songs/378195',
#    'apple_music_id': '882945383',
#    'apple_music_player_url': 'https://genius.com/songs/378195/apple_music_player',
#    'description': {'dom': {'tag': 'root',
#      'children': [{'tag': 'p',
#        'children': ['“Chandelier” was released as the lead single from Sia’s sixth studio album, ',
#         {'tag': 'em', 'children': ['1000 Forms Of Fear']},
#         '. Despite its soaring melody, the song has a sad theme describing the life of a “party girl”. On the track, Sia talks about her alcohol and drug addiction.']},
#       '',
#       {'tag': 'p',
#        'children': ['Sia has written songs for pop stars like ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Rihanna-diamonds-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/89794'},
#          'children': ['Rihanna']},
#         ', ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/Katy-perry-double-rainbow-lyrics',
#           'rel': 'noopener'},
#          'data': {'api_path': '/songs/239168'},
#          'children': ['Katy Perry']},
#         ', and ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://genius.com/artists/Britney-spears',
#           'rel': 'noopener'},
#          'data': {'api_path': '/artists/1052'},
#          'children': ['Britney Spears']},
#         ', but this time she saves the “swing from the chandelier” moment for her own angelic voice.']},
#       '',
#       {'tag': 'p',
#        'children': ['The song has been described by many as Sia’s breakthrough performance due to its huge commercial success and critical acclaim. Billboard named the track one of the most memorable choruses of all time.']},
#       '',
#       {'tag': 'p',
#        'children': [{'tag': 'a',
#          'attributes': {'href': 'https://genius.com/artists/Maddie-ziegler',
#           'rel': 'noopener'},
#          'data': {'api_path': '/artists/329063'},
#          'children': ['Maddie Ziegler']},
#         ' revealed in a ',
#         {'tag': 'a',
#          'attributes': {'href': 'https://www.youtube.com/watch?v=J2kHoNCpTGM',
#           'rel': 'noopener nofollow'},
#          'children': ['YouTube video']},
#         ' that the people on set said that the set was haunted, due to the building being very old. Being an eleven year old, she was scared to dance there on her own. Maddie also said that when Sia reached out to her, asking her to be in the music video, she thought she would be a back-up dancer:']},
#       '',
#       {'tag': 'blockquote',
#        'children': [{'tag': 'p',
#          'children': ['But when I got on set, it was just me in rehearsal.']}]}]}},
#    'embed_content': "<div id='rg_embed_link_378195' class='rg_embed_link' data-song-id='378195'>Read <a href='https://genius.com/Sia-chandelier-lyrics'>“Chandelier” by Sia</a> on Genius</div> <script crossorigin src='//genius.com/songs/378195/embed.js'></script>",
#    'featured_video': True,
#    'full_title': 'Chandelier by\xa0Sia',
#    'header_image_thumbnail_url': 'https://images.genius.com/4b681dde97d03ce4a93fb1515fb7219d.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/4b681dde97d03ce4a93fb1515fb7219d.600x600x1.jpg',
#    'id': 378195,
#    'lyrics_owner_id': 47098,
#    'lyrics_state': 'complete',
#    'path': '/Sia-chandelier-lyrics',
#    'pyongs_count': 426,
#    'recording_location': None,
#    'release_date': '2014-03-17',
#    'release_date_for_display': 'March 17, 2014',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/5bcfb76690b3fb068a317c76579b70b5.300x300x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/5bcfb76690b3fb068a317c76579b70b5.1000x1000x1.jpg',
#    'stats': {'accepted_annotations': 17,
#     'contributors': 122,
#     'iq_earners': 121,
#     'transcribers': 4,
#     'unreviewed_annotations': 0,
#     'verified_annotations': 15,
#     'concurrents': 3,
#     'hot': False,
#     'pageviews': 1579491},
#    'title': 'Chandelier',
#    'title_with_featured': 'Chandelier',
#    'url': 'https://genius.com/Sia-chandelier-lyrics',
#    'current_user_metadata': {'permissions': ['see_pageviews',
#      'view_apple_music_player',
#      'create_comment',
#      'view_song_story_gallery'],
#     'excluded_permissions': ['follow',
#      'award_transcription_iq',
#      'remove_transcription_iq',
#      'pyong',
#      'edit_lyrics',
#      'view_annotation_engagement_data',
#      'publish',
#      'unpublish',
#      'edit_spotify_details',
#      'hide',
#      'unhide',
#      'toggle_featured_video',
#      'add_pinned_annotation_to',
#      'add_community_annotation_to',
#      'destroy',
#      'mark_as_not_spam',
#      'edit_spotify_annotations_for',
#      'verify_lyrics',
#      'unverify_lyrics',
#      'edit_anything',
#      'edit_any_media',
#      'edit',
#      'rename',
#      'edit_tags',
#      'watch_fact_track',
#      'reindex',
#      'view_lyrics_synchronization',
#      'enable_media',
#      'disable_media',
#      'edit_lyrics_or_annotation_brackets',
#      'see_editorial_indicators',
#      'view_attribution_visualization',
#      'edit_annotation_brackets',
#      'preview_lyrics_for_export',
#      'hide_apple_player',
#      'unhide_apple_player',
#      'trigger_apple_match',
#      'mark_lyrics_evaluation_as_approved',
#      'mark_lyrics_evaluation_as_staff_approved',
#      'mark_lyrics_evaluation_as_unapproved',
#      'mark_lyrics_evaluation_as_un_staff_approved',
#      'view_transcriber_media_player',
#      'override_apple_match',
#      'edit_youtube_url',
#      'edit_soundcloud_url',
#      'edit_spotify_uuid',
#      'edit_vevo_url',
#      'moderate_annotations',
#      'create_annotation',
#      'see_short_id',
#      'manage_chart_item',
#      'create_tag',
#      'propose_lyrics_edit',
#      'moderate_lyrics_edit_proposals',
#      'view_react_song_page'],
#     'interactions': {'pyong': False, 'following': False},
#     'relationships': {},
#     'iq_by_action': {}},
#    'album': {'api_path': '/albums/104614',
#     'cover_art_url': 'https://images.genius.com/0a2dfec3681e8b19da8c37dd7ecf193c.1000x1000x1.jpg',
#     'full_title': '1000 Forms of Fear by Sia',
#     'id': 104614,
#     'name': '1000 Forms of Fear',
#     'url': 'https://genius.com/albums/Sia/1000-forms-of-fear',
#     'artist': {'api_path': '/artists/16775',
#      'header_image_url': 'https://images.genius.com/cb40ff6ba23119fdb3ec69073be7cf34.1000x427x1.jpg',
#      'id': 16775,
#      'image_url': 'https://images.genius.com/6bcd2bd1708eeae7282400f1e4be633f.600x600x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': True,
#      'name': 'Sia',
#      'url': 'https://genius.com/artists/Sia',
#      'iq': 6941}},
#    'custom_performances': [],
#    'description_annotation': {'_type': 'referent',
#     'annotator_id': 47098,
#     'annotator_login': 'notero',
#     'api_path': '/referents/3721376',
#     'classification': 'accepted',
#     'fragment': 'Chandelier',
#     'id': 3721376,
#     'is_description': True,
#     'path': '/3721376/Sia-chandelier/Chandelier',
#     'range': {'content': 'Chandelier'},
#     'song_id': 378195,
#     'url': 'https://genius.com/3721376/Sia-chandelier/Chandelier',
#     'verified_annotator_ids': [],
#     'annotatable': {'api_path': '/songs/378195',
#      'client_timestamps': {'updated_by_human_at': 1581124984,
#       'lyrics_updated_at': 1555509919},
#      'context': 'Sia',
#      'id': 378195,
#      'image_url': 'https://images.genius.com/5bcfb76690b3fb068a317c76579b70b5.1000x1000x1.jpg',
#      'link_title': 'Chandelier by\xa0Sia',
#      'title': 'Chandelier',
#      'type': 'Song',
#      'url': 'https://genius.com/Sia-chandelier-lyrics'},
#     'annotations': [{'api_path': '/annotations/3721376',
#       'body': {'dom': {'tag': 'root',
#         'children': [{'tag': 'p',
#           'children': ['“Chandelier” was released as the lead single from Sia’s sixth studio album, ',
#            {'tag': 'em', 'children': ['1000 Forms Of Fear']},
#            '. Despite its soaring melody, the song has a sad theme describing the life of a “party girl”. On the track, Sia talks about her alcohol and drug addiction.']},
#          '',
#          {'tag': 'p',
#           'children': ['Sia has written songs for pop stars like ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Rihanna-diamonds-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/89794'},
#             'children': ['Rihanna']},
#            ', ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/Katy-perry-double-rainbow-lyrics',
#              'rel': 'noopener'},
#             'data': {'api_path': '/songs/239168'},
#             'children': ['Katy Perry']},
#            ', and ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://genius.com/artists/Britney-spears',
#              'rel': 'noopener'},
#             'data': {'api_path': '/artists/1052'},
#             'children': ['Britney Spears']},
#            ', but this time she saves the “swing from the chandelier” moment for her own angelic voice.']},
#          '',
#          {'tag': 'p',
#           'children': ['The song has been described by many as Sia’s breakthrough performance due to its huge commercial success and critical acclaim. Billboard named the track one of the most memorable choruses of all time.']},
#          '',
#          {'tag': 'p',
#           'children': [{'tag': 'a',
#             'attributes': {'href': 'https://genius.com/artists/Maddie-ziegler',
#              'rel': 'noopener'},
#             'data': {'api_path': '/artists/329063'},
#             'children': ['Maddie Ziegler']},
#            ' revealed in a ',
#            {'tag': 'a',
#             'attributes': {'href': 'https://www.youtube.com/watch?v=J2kHoNCpTGM',
#              'rel': 'noopener nofollow'},
#             'children': ['YouTube video']},
#            ' that the people on set said that the set was haunted, due to the building being very old. Being an eleven year old, she was scared to dance there on her own. Maddie also said that when Sia reached out to her, asking her to be in the music video, she thought she would be a back-up dancer:']},
#          '',
#          {'tag': 'blockquote',
#           'children': [{'tag': 'p',
#             'children': ['But when I got on set, it was just me in rehearsal.']}]}]}},
#       'comment_count': 5,
#       'community': True,
#       'custom_preview': None,
#       'has_voters': True,
#       'id': 3721376,
#       'pinned': False,
#       'share_url': 'https://genius.com/3721376',
#       'source': None,
#       'state': 'accepted',
#       'url': 'https://genius.com/3721376/Sia-chandelier/Chandelier',
#       'verified': False,
#       'votes_total': 136,
#       'current_user_metadata': {'permissions': ['create_comment'],
#        'excluded_permissions': ['vote',
#         'edit',
#         'cosign',
#         'uncosign',
#         'destroy',
#         'accept',
#         'reject',
#         'see_unreviewed',
#         'clear_votes',
#         'propose_edit_to',
#         'pin_to_profile',
#         'unpin_from_profile',
#         'update_source',
#         'edit_custom_preview'],
#        'interactions': {'cosign': False, 'pyong': False, 'vote': None},
#        'iq_by_action': {}},
#       'authors': [{'attribution': 0.42391304347826086,
#         'pinned_role': None,
#         'user': {'api_path': '/users/2557222',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/50313782b5b3ebfa8d920c5e2593a3b2',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/50313782b5b3ebfa8d920c5e2593a3b2',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/50313782b5b3ebfa8d920c5e2593a3b2',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/50313782b5b3ebfa8d920c5e2593a3b2',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.genius.com/019f579c5a28845fb2060871e94c0c6c.864x360x1.jpg',
#          'human_readable_role_for_display': 'Editor',
#          'id': 2557222,
#          'iq': 86858,
#          'login': 'ssaa10dec',
#          'name': 'Ssaa10dec',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/ssaa10dec',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.40217391304347827,
#         'pinned_role': None,
#         'user': {'api_path': '/users/8901159',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/b0318a7989e0baa362a5b05362c559f4',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/b0318a7989e0baa362a5b05362c559f4',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/b0318a7989e0baa362a5b05362c559f4',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/b0318a7989e0baa362a5b05362c559f4',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://s3.amazonaws.com/filepicker-images-rapgenius/lz0u9ytsjro',
#          'human_readable_role_for_display': 'Contributor',
#          'id': 8901159,
#          'iq': 2887,
#          'login': 'TYFNA',
#          'name': 'TYFNA',
#          'role_for_display': 'contributor',
#          'url': 'https://genius.com/TYFNA',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.15217391304347827,
#         'pinned_role': None,
#         'user': {'api_path': '/users/150910',
#          'avatar': {'tiny': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/tiny/zmkfqkztReGZ0zuiuLXp.png',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/thumb/zmkfqkztReGZ0zuiuLXp.png',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/small/zmkfqkztReGZ0zuiuLXp.png',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://s3.amazonaws.com/rapgenius/avatars/medium/zmkfqkztReGZ0zuiuLXp.png',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://s3.amazonaws.com/rapgenius/avatars/medium/zmkfqkztReGZ0zuiuLXp.png',
#          'human_readable_role_for_display': 'Editor',
#          'id': 150910,
#          'iq': 139167,
#          'login': 'Spinelli',
#          'name': 'Spinelli',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/Spinelli',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.016304347826086956,
#         'pinned_role': None,
#         'user': {'api_path': '/users/458792',
#          'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/e2bd00d48b48b2489eb3f2a969dd1ed3',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.genius.com/avatars/thumb/e2bd00d48b48b2489eb3f2a969dd1ed3',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.genius.com/avatars/small/e2bd00d48b48b2489eb3f2a969dd1ed3',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.genius.com/avatars/medium/e2bd00d48b48b2489eb3f2a969dd1ed3',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.genius.com/e8a303ab79861711fb6aa79f1e231f90.960x617x1.jpg',
#          'human_readable_role_for_display': 'Moderator',
#          'id': 458792,
#          'iq': 308415,
#          'login': 'Skhills',
#          'name': 'Skhills',
#          'role_for_display': 'moderator',
#          'url': 'https://genius.com/Skhills',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}},
#        {'attribution': 0.005434782608695652,
#         'pinned_role': None,
#         'user': {'api_path': '/users/12128',
#          'avatar': {'tiny': {'url': 'https://images.rapgenius.com/avatars/tiny/b0afb1ccd43ff1285d5ec9cd111713a4',
#            'bounding_box': {'width': 16, 'height': 16}},
#           'thumb': {'url': 'https://images.rapgenius.com/avatars/thumb/b0afb1ccd43ff1285d5ec9cd111713a4',
#            'bounding_box': {'width': 32, 'height': 32}},
#           'small': {'url': 'https://images.rapgenius.com/avatars/small/b0afb1ccd43ff1285d5ec9cd111713a4',
#            'bounding_box': {'width': 100, 'height': 100}},
#           'medium': {'url': 'https://images.rapgenius.com/avatars/medium/b0afb1ccd43ff1285d5ec9cd111713a4',
#            'bounding_box': {'width': 300, 'height': 400}}},
#          'header_image_url': 'https://images.rapgenius.com/avatars/medium/b0afb1ccd43ff1285d5ec9cd111713a4',
#          'human_readable_role_for_display': 'Editor',
#          'id': 12128,
#          'iq': 181828,
#          'login': 'dalmo',
#          'name': 'Dalmo Mendonça',
#          'role_for_display': 'editor',
#          'url': 'https://genius.com/dalmo',
#          'current_user_metadata': {'permissions': [],
#           'excluded_permissions': ['follow'],
#           'interactions': {'following': False}}}}],
#       'cosigned_by': [],
#       'rejection_comment': None,
#       'verified_by': None}]},
#    'featured_artists': [],
#    'lyrics_marked_complete_by': None,
#    'media': [{'provider': 'youtube',
#      'start': 10,
#      'type': 'video',
#      'url': 'http://www.youtube.com/watch?v=2vjPBrBU-TM'},
#     {'native_uri': 'spotify:track:4VrWlk8IQxevMvERoX08iC',
#      'provider': 'spotify',
#      'type': 'audio',
#      'url': 'https://open.spotify.com/track/4VrWlk8IQxevMvERoX08iC'},
#     {'attribution': 'siamusic',
#      'provider': 'soundcloud',
#      'type': 'audio',
#      'url': 'https://soundcloud.com/siamusic/sia-chandelier'}],
#    'primary_artist': {'api_path': '/artists/16775',
#     'header_image_url': 'https://images.genius.com/cb40ff6ba23119fdb3ec69073be7cf34.1000x427x1.jpg',
#     'id': 16775,
#     'image_url': 'https://images.genius.com/6bcd2bd1708eeae7282400f1e4be633f.600x600x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': True,
#     'name': 'Sia',
#     'url': 'https://genius.com/artists/Sia',
#     'iq': 6941},
#    'producer_artists': [{'api_path': '/artists/55444',
#      'header_image_url': 'https://images.genius.com/564ae98a950634822f648f292b113e78.600x400x1.jpg',
#      'id': 55444,
#      'image_url': 'https://images.genius.com/1e4b1db8fef9629acc9f622e3f4ecbf9.440x440x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Greg Kurstin',
#      'url': 'https://genius.com/artists/Greg-kurstin'},
#     {'api_path': '/artists/154199',
#      'header_image_url': 'https://images.genius.com/bf7f5c1b74797d542e07b862e77dd8dd.600x402x1.jpg',
#      'id': 154199,
#      'image_url': 'https://images.genius.com/bf7f5c1b74797d542e07b862e77dd8dd.600x402x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Jesse Shatkin',
#      'url': 'https://genius.com/artists/Jesse-shatkin'}],
#    'song_relationships': [{'relationship_type': 'samples',
#      'type': 'samples',
#      'songs': []},
#     {'relationship_type': 'sampled_in',
#      'type': 'sampled_in',
#      'songs': [{'annotation_count': 3,
#        'api_path': '/songs/3097666',
#        'full_title': 'Luis Fonsi & Daddy Yankee - Despacito Remix ft. Justin Bieber (SING OFF vs. Pixie Lott) by\xa0Conor\xa0Maynard (Ft.\xa0Pixie\xa0Lott)',
#        'header_image_thumbnail_url': 'https://images.genius.com/40800fa7d2b6fe66db71c7ad51a957fc.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/40800fa7d2b6fe66db71c7ad51a957fc.1000x1000x1.jpg',
#        'id': 3097666,
#        'lyrics_owner_id': 4440506,
#        'lyrics_state': 'complete',
#        'path': '/Conor-maynard-luis-fonsi-and-daddy-yankee-despacito-remix-ft-justin-bieber-sing-off-vs-pixie-lott-lyrics',
#        'pyongs_count': 2,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/40800fa7d2b6fe66db71c7ad51a957fc.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/40800fa7d2b6fe66db71c7ad51a957fc.1000x1000x1.jpg',
#        'stats': {'unreviewed_annotations': 3,
#         'hot': False,
#         'pageviews': 29007},
#        'title': 'Luis Fonsi & Daddy Yankee - Despacito Remix ft. Justin Bieber (SING OFF vs. Pixie Lott)',
#        'title_with_featured': 'Luis Fonsi & Daddy Yankee - Despacito Remix ft. Justin Bieber (SING OFF vs. Pixie Lott) (Ft.\xa0Pixie\xa0Lott)',
#        'url': 'https://genius.com/Conor-maynard-luis-fonsi-and-daddy-yankee-despacito-remix-ft-justin-bieber-sing-off-vs-pixie-lott-lyrics',
#        'primary_artist': {'api_path': '/artists/21941',
#         'header_image_url': 'https://images.genius.com/2d3a8a588d504ca90e4049b2d3ec9c83.1000x525x1.jpg',
#         'id': 21941,
#         'image_url': 'https://images.genius.com/40800fa7d2b6fe66db71c7ad51a957fc.1000x1000x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': True,
#         'name': 'Conor Maynard',
#         'url': 'https://genius.com/artists/Conor-maynard',
#         'iq': 261}},
#       {'annotation_count': 0,
#        'api_path': '/songs/3338243',
#        'full_title': 'Upside Down by\xa0Kevin\xa0LaSean',
#        'header_image_thumbnail_url': 'https://images.genius.com/92fb0fa3ab530b815b814786f5f8bf21.300x169x1.jpg',
#        'header_image_url': 'https://images.genius.com/92fb0fa3ab530b815b814786f5f8bf21.1000x563x1.jpg',
#        'id': 3338243,
#        'lyrics_owner_id': 5541116,
#        'lyrics_state': 'complete',
#        'path': '/Kevin-lasean-upside-down-lyrics',
#        'pyongs_count': 1,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/e60052837bf47aadca0489ed14abd883.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/e60052837bf47aadca0489ed14abd883.500x500x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Upside Down',
#        'title_with_featured': 'Upside Down',
#        'url': 'https://genius.com/Kevin-lasean-upside-down-lyrics',
#        'primary_artist': {'api_path': '/artists/635507',
#         'header_image_url': 'https://images.genius.com/0fd2a33a9f17930df49639e3ba50064a.1000x333x1.jpg',
#         'id': 635507,
#         'image_url': 'https://images.genius.com/88f9c8fa0591acbb5f4057a428968d2a.400x400x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Kevin LaSean',
#         'url': 'https://genius.com/artists/Kevin-lasean'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/3471668',
#        'full_title': 'Materialstic Girl by\xa0Lance\xa0Is A Genius (Ft.\xa0AprilFoolChild)',
#        'header_image_thumbnail_url': 'https://images.genius.com/b92dee2233cf591aca4135e66f0a6684.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/b92dee2233cf591aca4135e66f0a6684.900x900x1.jpg',
#        'id': 3471668,
#        'lyrics_owner_id': 1480147,
#        'lyrics_state': 'complete',
#        'path': '/Lance-is-a-genius-materialstic-girl-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/b92dee2233cf591aca4135e66f0a6684.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/b92dee2233cf591aca4135e66f0a6684.900x900x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Materialstic Girl',
#        'title_with_featured': 'Materialstic Girl (Ft.\xa0AprilFoolChild)',
#        'url': 'https://genius.com/Lance-is-a-genius-materialstic-girl-lyrics',
#        'primary_artist': {'api_path': '/artists/1166062',
#         'header_image_url': 'https://images.genius.com/a59f32f42c14eee2eb54e90ceab5f145.512x512x1.jpg',
#         'id': 1166062,
#         'image_url': 'https://images.genius.com/a59f32f42c14eee2eb54e90ceab5f145.512x512x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': True,
#         'name': 'Lance Is A Genius',
#         'url': 'https://genius.com/artists/Lance-is-a-genius',
#         'iq': 82}},
#       {'annotation_count': 1,
#        'api_path': '/songs/3793742',
#        'full_title': '8 Times a Week (2018 Tony Awards) by\xa0Josh\xa0Groban & Sara Bareilles',
#        'header_image_thumbnail_url': 'https://images.genius.com/1cf515ea9f2f71024fd8a9e8d6640124.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/1cf515ea9f2f71024fd8a9e8d6640124.1000x1000x1.jpg',
#        'id': 3793742,
#        'lyrics_owner_id': 2977739,
#        'lyrics_state': 'complete',
#        'path': '/Josh-groban-and-sara-bareilles-8-times-a-week-2018-tony-awards-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/1cf515ea9f2f71024fd8a9e8d6640124.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/1cf515ea9f2f71024fd8a9e8d6640124.1000x1000x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': '8 Times a Week (2018 Tony Awards)',
#        'title_with_featured': '8 Times a Week (2018 Tony Awards)',
#        'url': 'https://genius.com/Josh-groban-and-sara-bareilles-8-times-a-week-2018-tony-awards-lyrics',
#        'primary_artist': {'api_path': '/artists/1504226',
#         'header_image_url': 'https://images.genius.com/49c131a8a497ce7e093374d4e4047d05.1000x1000x1.jpg',
#         'id': 1504226,
#         'image_url': 'https://images.genius.com/49c131a8a497ce7e093374d4e4047d05.1000x1000x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Josh Groban & Sara Bareilles',
#         'url': 'https://genius.com/artists/Josh-groban-and-sara-bareilles'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/4608870',
#        'full_title': 'STANISLAV PETROV. by\xa0Jon\xa0Bois',
#        'header_image_thumbnail_url': 'https://images.genius.com/699be7b42908c5e7137ef9867828aff1.300x200x1.webp',
#        'header_image_url': 'https://images.genius.com/699be7b42908c5e7137ef9867828aff1.920x613x1.webp',
#        'id': 4608870,
#        'lyrics_owner_id': 2074198,
#        'lyrics_state': 'unreleased',
#        'path': '/Jon-bois-stanislav-petrov-annotated',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/699be7b42908c5e7137ef9867828aff1.300x200x1.webp',
#        'song_art_image_url': 'https://images.genius.com/699be7b42908c5e7137ef9867828aff1.920x613x1.webp',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'STANISLAV PETROV.',
#        'title_with_featured': 'STANISLAV PETROV.',
#        'url': 'https://genius.com/Jon-bois-stanislav-petrov-annotated',
#        'primary_artist': {'api_path': '/artists/1846138',
#         'header_image_url': 'https://images.genius.com/8385a3e89fa8eda1f82c0ecb44c6ccaa.900x900x1.jpg',
#         'id': 1846138,
#         'image_url': 'https://images.genius.com/bb206d7bfc4e11b0849742b0a96f6b19.300x300x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Jon Bois',
#         'url': 'https://genius.com/artists/Jon-bois'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/4727118',
#        'full_title': 'Love Generator (Keygen) by\xa0Eatbones',
#        'header_image_thumbnail_url': 'https://images.genius.com/2eed01bf5a046302679769e36091520b.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/2eed01bf5a046302679769e36091520b.640x640x1.jpg',
#        'id': 4727118,
#        'lyrics_owner_id': 2463616,
#        'lyrics_state': 'complete',
#        'path': '/Eatbones-love-generator-keygen-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/2eed01bf5a046302679769e36091520b.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/2eed01bf5a046302679769e36091520b.640x640x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Love Generator (Keygen)',
#        'title_with_featured': 'Love Generator (Keygen)',
#        'url': 'https://genius.com/Eatbones-love-generator-keygen-lyrics',
#        'primary_artist': {'api_path': '/artists/1272410',
#         'header_image_url': 'https://images.genius.com/c40c92b9e4aeaa298c53635efde138b2.640x640x1.jpg',
#         'id': 1272410,
#         'image_url': 'https://images.genius.com/e310dade510d85ff228762850201157c.640x640x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Eatbones',
#         'url': 'https://genius.com/artists/Eatbones'}},
#       {'annotation_count': 7,
#        'api_path': '/songs/4886256',
#        'full_title': '肥媽有話兒 by\xa0FatMaaaaaa',
#        'header_image_thumbnail_url': 'https://images.genius.com/928be40b13b5f4923258a7b4cac1e049.129x129x1.png',
#        'header_image_url': 'https://images.genius.com/928be40b13b5f4923258a7b4cac1e049.129x129x1.png',
#        'id': 4886256,
#        'lyrics_owner_id': 9391716,
#        'lyrics_state': 'complete',
#        'path': '/Fatmaaaaaa--lyrics',
#        'pyongs_count': 1,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/928be40b13b5f4923258a7b4cac1e049.129x129x1.png',
#        'song_art_image_url': 'https://images.genius.com/928be40b13b5f4923258a7b4cac1e049.129x129x1.png',
#        'stats': {'unreviewed_annotations': 7, 'hot': False},
#        'title': '肥媽有話兒',
#        'title_with_featured': '肥媽有話兒',
#        'url': 'https://genius.com/Fatmaaaaaa--lyrics',
#        'primary_artist': {'api_path': '/artists/1955744',
#         'header_image_url': 'https://images.genius.com/928be40b13b5f4923258a7b4cac1e049.129x129x1.png',
#         'id': 1955744,
#         'image_url': 'https://images.genius.com/928be40b13b5f4923258a7b4cac1e049.129x129x1.png',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'FatMaaaaaa',
#         'url': 'https://genius.com/artists/Fatmaaaaaa'}}]},
#     {'relationship_type': 'interpolates', 'type': 'interpolates', 'songs': []},
#     {'relationship_type': 'interpolated_by',
#      'type': 'interpolated_by',
#      'songs': []},
#     {'relationship_type': 'cover_of', 'type': 'cover_of', 'songs': []},
#     {'relationship_type': 'covered_by',
#      'type': 'covered_by',
#      'songs': [{'annotation_count': 1,
#        'api_path': '/songs/1849976',
#        'full_title': 'Chandelier by\xa0Jasmine\xa0Thompson',
#        'header_image_thumbnail_url': 'https://images.rapgenius.com/9381921195ec2a406b68569c628f03e9.300x300x1.jpg',
#        'header_image_url': 'https://images.rapgenius.com/9381921195ec2a406b68569c628f03e9.1000x1000x1.jpg',
#        'id': 1849976,
#        'lyrics_owner_id': 1549345,
#        'lyrics_state': 'complete',
#        'path': '/Jasmine-thompson-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.rapgenius.com/9381921195ec2a406b68569c628f03e9.300x300x1.jpg',
#        'song_art_image_url': 'https://images.rapgenius.com/9381921195ec2a406b68569c628f03e9.1000x1000x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Jasmine-thompson-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/276414',
#         'header_image_url': 'https://images.genius.com/540b0f57e19edbc0f1454534cb3b70b3.1000x333x1.jpg',
#         'id': 276414,
#         'image_url': 'https://images.genius.com/6dea44c90edada09d2d37eab284e78f4.1000x1000x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': True,
#         'name': 'Jasmine Thompson',
#         'url': 'https://genius.com/artists/Jasmine-thompson',
#         'iq': 390}},
#       {'annotation_count': 1,
#        'api_path': '/songs/1933665',
#        'full_title': 'Chandelier (Live) by\xa0Sara\xa0Bareilles',
#        'header_image_thumbnail_url': 'https://images.genius.com/09285c8fd117465dd8744abccf74753d.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/09285c8fd117465dd8744abccf74753d.615x615x1.jpg',
#        'id': 1933665,
#        'lyrics_owner_id': 269182,
#        'lyrics_state': 'complete',
#        'path': '/Sara-bareilles-chandelier-live-lyrics',
#        'pyongs_count': 1,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/09285c8fd117465dd8744abccf74753d.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/09285c8fd117465dd8744abccf74753d.615x615x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier (Live)',
#        'title_with_featured': 'Chandelier (Live)',
#        'url': 'https://genius.com/Sara-bareilles-chandelier-live-lyrics',
#        'primary_artist': {'api_path': '/artists/19936',
#         'header_image_url': 'https://images.genius.com/5c17d46ef02973bdbecb331df98bff74.540x243x1.png',
#         'id': 19936,
#         'image_url': 'https://images.genius.com/09285c8fd117465dd8744abccf74753d.615x615x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Sara Bareilles',
#         'url': 'https://genius.com/artists/Sara-bareilles'}},
#       {'annotation_count': 1,
#        'api_path': '/songs/1959630',
#        'full_title': 'Chandelier by\xa0Glee\xa0Cast',
#        'header_image_thumbnail_url': 'https://images.genius.com/b19b4591975b14a018904cda3d08e58e.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/b19b4591975b14a018904cda3d08e58e.1000x1000x1.jpg',
#        'id': 1959630,
#        'lyrics_owner_id': 359109,
#        'lyrics_state': 'complete',
#        'path': '/Glee-cast-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/b19b4591975b14a018904cda3d08e58e.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/b19b4591975b14a018904cda3d08e58e.1000x1000x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Glee-cast-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/275474',
#         'header_image_url': 'https://images.genius.com/f5de6b17c7ecc5b212af8b0641823cd9.500x500x1.png',
#         'id': 275474,
#         'image_url': 'https://images.genius.com/acb2b6cc07b9ffa614cbae768d546e84.910x910x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Glee Cast',
#         'url': 'https://genius.com/artists/Glee-cast'}},
#       {'annotation_count': 1,
#        'api_path': '/songs/1994093',
#        'full_title': 'Chandelier by\xa0Twenty\xa0One Two',
#        'header_image_thumbnail_url': 'https://assets.genius.com/images/default_cover_image.png?1582666308',
#        'header_image_url': 'https://assets.genius.com/images/default_cover_image.png?1582666308',
#        'id': 1994093,
#        'lyrics_owner_id': 269182,
#        'lyrics_state': 'complete',
#        'path': '/Twenty-one-two-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://assets.genius.com/images/default_cover_image.png?1582666308',
#        'song_art_image_url': 'https://assets.genius.com/images/default_cover_image.png?1582666308',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Twenty-one-two-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/532094',
#         'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1582666308',
#         'id': 532094,
#         'image_url': 'https://assets.genius.com/images/default_avatar_300.png?1582666308',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Twenty One Two',
#         'url': 'https://genius.com/artists/Twenty-one-two'}},
#       {'annotation_count': 1,
#        'api_path': '/songs/2047780',
#        'full_title': 'Chandelier by\xa0Emily\xa0West',
#        'header_image_thumbnail_url': 'https://images.genius.com/fdca043324f4509a96a287aa2f1e551b.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/fdca043324f4509a96a287aa2f1e551b.500x500x1.jpg',
#        'id': 2047780,
#        'lyrics_owner_id': 1549345,
#        'lyrics_state': 'complete',
#        'path': '/Emily-west-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/fdca043324f4509a96a287aa2f1e551b.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/fdca043324f4509a96a287aa2f1e551b.500x500x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Emily-west-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/375317',
#         'header_image_url': 'https://images.genius.com/3367168b19e670411eec5ce00133fac2.1000x667x1.jpg',
#         'id': 375317,
#         'image_url': 'https://images.genius.com/61b59877371e3c0599617aa30664a0f4.683x683x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Emily West',
#         'url': 'https://genius.com/artists/Emily-west'}},
#       {'annotation_count': 1,
#        'api_path': '/songs/2076757',
#        'full_title': 'Chandelier (Acoustic) by\xa0Skylar\xa0Stecker',
#        'header_image_thumbnail_url': 'https://images.genius.com/6f415791f0d4b6277596726a719f1e4e.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/6f415791f0d4b6277596726a719f1e4e.800x800x1.jpg',
#        'id': 2076757,
#        'lyrics_owner_id': 1549345,
#        'lyrics_state': 'complete',
#        'path': '/Skylar-stecker-chandelier-acoustic-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/6f415791f0d4b6277596726a719f1e4e.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/6f415791f0d4b6277596726a719f1e4e.800x800x1.jpg',
#        'stats': {'unreviewed_annotations': 1, 'hot': False},
#        'title': 'Chandelier (Acoustic)',
#        'title_with_featured': 'Chandelier (Acoustic)',
#        'url': 'https://genius.com/Skylar-stecker-chandelier-acoustic-lyrics',
#        'primary_artist': {'api_path': '/artists/406230',
#         'header_image_url': 'https://images.genius.com/35d7f7ae819665fd7a355b201d726f37.1000x563x1.jpg',
#         'id': 406230,
#         'image_url': 'https://images.genius.com/2566ef5d91b3cbd284ca792158b83ee3.1000x1000x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': True,
#         'name': 'Skylar Stecker',
#         'url': 'https://genius.com/artists/Skylar-stecker',
#         'iq': 841}},
#       {'annotation_count': 1,
#        'api_path': '/songs/2099902',
#        'full_title': 'Chandelier by\xa0Coco\xa0Jones',
#        'header_image_thumbnail_url': 'https://images.genius.com/a5ab5fd889ca020502525ba03686ccf8.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/a5ab5fd889ca020502525ba03686ccf8.800x800x1.jpg',
#        'id': 2099902,
#        'lyrics_owner_id': 5888857,
#        'lyrics_state': 'complete',
#        'path': '/Coco-jones-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/a5ab5fd889ca020502525ba03686ccf8.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/a5ab5fd889ca020502525ba03686ccf8.800x800x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Coco-jones-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/21758',
#         'header_image_url': 'https://images.rapgenius.com/avatars/medium/d0d26d00aff27445dd7e0440522f1854',
#         'id': 21758,
#         'image_url': 'https://images.rapgenius.com/avatars/medium/d0d26d00aff27445dd7e0440522f1854',
#         'is_meme_verified': False,
#         'is_verified': True,
#         'name': 'Coco Jones',
#         'url': 'https://genius.com/artists/Coco-jones',
#         'iq': 466}},
#       {'annotation_count': 1,
#        'api_path': '/songs/2125733',
#        'full_title': "Chandelier by\xa0Scott\xa0Bradlee's Postmodern Jukebox (Ft.\xa0Puddles\xa0Pity Party)",
#        'header_image_thumbnail_url': 'https://images.genius.com/8e684e34a605fcb275476a94840daf6a.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/8e684e34a605fcb275476a94840daf6a.480x480x1.jpg',
#        'id': 2125733,
#        'lyrics_owner_id': 269182,
#        'lyrics_state': 'complete',
#        'path': '/Scott-bradlees-postmodern-jukebox-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/8e684e34a605fcb275476a94840daf6a.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/8e684e34a605fcb275476a94840daf6a.480x480x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier (Ft.\xa0Puddles\xa0Pity Party)',
#        'url': 'https://genius.com/Scott-bradlees-postmodern-jukebox-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/523216',
#         'header_image_url': 'https://images.genius.com/cba9980f0a6387fdc88b1d74386f5881.1000x653x1.jpg',
#         'id': 523216,
#         'image_url': 'https://images.genius.com/2d424bf3c3c7a60294829949e341cf7f.900x900x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Scott Bradlee’s Postmodern Jukebox',
#         'url': 'https://genius.com/artists/Scott-bradlees-postmodern-jukebox'}},
#       {'annotation_count': 2,
#        'api_path': '/songs/2147780',
#        'full_title': 'Chandelier by\xa0PVRIS',
#        'header_image_thumbnail_url': 'https://images.genius.com/11e7914e456b0948c15775044397a111.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/11e7914e456b0948c15775044397a111.750x750x1.jpg',
#        'id': 2147780,
#        'lyrics_owner_id': 1215397,
#        'lyrics_state': 'complete',
#        'path': '/Pvris-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/11e7914e456b0948c15775044397a111.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/11e7914e456b0948c15775044397a111.750x750x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 5220},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Pvris-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/234524',
#         'header_image_url': 'https://images.genius.com/3c95b7d3391ceb306344b16cca1f5379.960x639x1.jpg',
#         'id': 234524,
#         'image_url': 'https://images.genius.com/ccc14f5a8baa7c68a179b2482cd9ab3d.800x800x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'PVRIS',
#         'url': 'https://genius.com/artists/Pvris'}},
#       {'annotation_count': 1,
#        'api_path': '/songs/2222922',
#        'full_title': 'Chandelier (Acoustic) by\xa0Savannah\xa0Outen',
#        'header_image_thumbnail_url': 'https://images.genius.com/f5c43a815525b38262ba591942397bcc.300x300x1.png',
#        'header_image_url': 'https://images.genius.com/f5c43a815525b38262ba591942397bcc.620x620x1.png',
#        'id': 2222922,
#        'lyrics_owner_id': 1549345,
#        'lyrics_state': 'complete',
#        'path': '/Savannah-outen-chandelier-acoustic-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/f5c43a815525b38262ba591942397bcc.300x300x1.png',
#        'song_art_image_url': 'https://images.genius.com/f5c43a815525b38262ba591942397bcc.620x620x1.png',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier (Acoustic)',
#        'title_with_featured': 'Chandelier (Acoustic)',
#        'url': 'https://genius.com/Savannah-outen-chandelier-acoustic-lyrics',
#        'primary_artist': {'api_path': '/artists/383874',
#         'header_image_url': 'https://images.genius.com/77088511cc58a7a3f8f747861ed6f196.996x603x1.jpg',
#         'id': 383874,
#         'image_url': 'https://images.genius.com/f5c43a815525b38262ba591942397bcc.620x620x1.png',
#         'is_meme_verified': False,
#         'is_verified': True,
#         'name': 'Savannah Outen',
#         'url': 'https://genius.com/artists/Savannah-outen',
#         'iq': 350}},
#       {'annotation_count': 1,
#        'api_path': '/songs/2248392',
#        'full_title': 'Chandelier by\xa0Nick\xa0Pitera',
#        'header_image_thumbnail_url': 'https://images.genius.com/ad4d94f3bee4895204b58d0d198b6179.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/ad4d94f3bee4895204b58d0d198b6179.541x541x1.jpg',
#        'id': 2248392,
#        'lyrics_owner_id': 1549345,
#        'lyrics_state': 'complete',
#        'path': '/Nick-pitera-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/ad4d94f3bee4895204b58d0d198b6179.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/ad4d94f3bee4895204b58d0d198b6179.541x541x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Nick-pitera-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/405897',
#         'header_image_url': 'https://images.genius.com/d9f97c566046749121c188c87274ca90.1000x563x1.jpg',
#         'id': 405897,
#         'image_url': 'https://images.genius.com/ad4d94f3bee4895204b58d0d198b6179.541x541x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Nick Pitera',
#         'url': 'https://genius.com/artists/Nick-pitera'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/2424849',
#        'full_title': 'Chandelier by\xa0Normandie',
#        'header_image_thumbnail_url': 'https://images.genius.com/9b87e4bc0b865b11c28aa591b4e939b5.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/9b87e4bc0b865b11c28aa591b4e939b5.800x800x1.jpg',
#        'id': 2424849,
#        'lyrics_owner_id': 321054,
#        'lyrics_state': 'complete',
#        'path': '/Normandie-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/9b87e4bc0b865b11c28aa591b4e939b5.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/9b87e4bc0b865b11c28aa591b4e939b5.800x800x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Normandie-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/484327',
#         'header_image_url': 'https://images.genius.com/632445ae1af65bc62e42607168ae6023.1000x573x1.jpg',
#         'id': 484327,
#         'image_url': 'https://images.genius.com/378be20b6c6f63a9e65e37bb2f0071d8.1000x1000x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': True,
#         'name': 'Normandie',
#         'url': 'https://genius.com/artists/Normandie',
#         'iq': 116}},
#       {'annotation_count': 0,
#        'api_path': '/songs/2929265',
#        'full_title': 'Chandelier by\xa0Trent\xa0Harmon',
#        'header_image_thumbnail_url': 'https://images.genius.com/7bcabbd74ab070f7d0323c509de270a1.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/7bcabbd74ab070f7d0323c509de270a1.570x570x1.jpg',
#        'id': 2929265,
#        'lyrics_owner_id': 1373359,
#        'lyrics_state': 'complete',
#        'path': '/Trent-harmon-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/7bcabbd74ab070f7d0323c509de270a1.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/7bcabbd74ab070f7d0323c509de270a1.570x570x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Trent-harmon-chandelier-lyrics',
# ...
#         'url': 'https://genius.com/artists/Jordan-smith'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/3273379',
#        'full_title': 'Best of 2014: Problem / Boom Clap / Rude / Am I Wrong / All About That Bass / All of Me / Chandelier / Blank Space / Not a Bad Thing / Happy by\xa0Anthem\xa0Lights',
#        'header_image_thumbnail_url': 'https://images.genius.com/b8be282f2f4d548ebbdc70ba5fe05e1e.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/b8be282f2f4d548ebbdc70ba5fe05e1e.1000x1000x1.jpg',
#        'id': 3273379,
#        'lyrics_owner_id': 5660432,
#        'lyrics_state': 'complete',
#        'path': '/Anthem-lights-best-of-2014-problem-boom-clap-rude-am-i-wrong-all-about-that-bass-all-of-me-chandelier-blank-space-not-a-bad-thing-happy-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/b8be282f2f4d548ebbdc70ba5fe05e1e.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/b8be282f2f4d548ebbdc70ba5fe05e1e.1000x1000x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Best of 2014: Problem / Boom Clap / Rude / Am I Wrong / All About That Bass / All of Me / Chandelier / Blank Space / Not a Bad Thing / Happy',
#        'title_with_featured': 'Best of 2014: Problem / Boom Clap / Rude / Am I Wrong / All About That Bass / All of Me / Chandelier / Blank Space / Not a Bad Thing / Happy',
#        'url': 'https://genius.com/Anthem-lights-best-of-2014-problem-boom-clap-rude-am-i-wrong-all-about-that-bass-all-of-me-chandelier-blank-space-not-a-bad-thing-happy-lyrics',
#        'primary_artist': {'api_path': '/artists/215403',
#         'header_image_url': 'https://images.genius.com/cb91957189eb69655565e2484da97e39.1000x667x1.jpg',
#         'id': 215403,
#         'image_url': 'https://images.genius.com/9f0cd6a94f119bccccf3eb451a9f989a.640x640x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Anthem Lights',
#         'url': 'https://genius.com/artists/Anthem-lights'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/4368635',
#        'full_title': 'Chandelier by\xa0Gladys\xa0Knight',
#        'header_image_thumbnail_url': 'https://images.genius.com/86f65d7aec3ed5b72cf0b8815f631034.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/86f65d7aec3ed5b72cf0b8815f631034.899x899x1.jpg',
#        'id': 4368635,
#        'lyrics_owner_id': 5667167,
#        'lyrics_state': 'complete',
#        'path': '/Gladys-knight-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/86f65d7aec3ed5b72cf0b8815f631034.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/86f65d7aec3ed5b72cf0b8815f631034.899x899x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Gladys-knight-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/40272',
#         'header_image_url': 'https://images.genius.com/20343711f9a10f7c91da06d39abf9ff8.282x282x1.jpg',
#         'id': 40272,
#         'image_url': 'https://images.genius.com/20343711f9a10f7c91da06d39abf9ff8.282x282x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Gladys Knight',
#         'url': 'https://genius.com/artists/Gladys-knight'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/4424735',
#        'full_title': 'Chandelier by\xa0Kain\xa0Rivers',
#        'header_image_thumbnail_url': 'https://images.genius.com/67991c4d16db352a66014dcb8dfb4972.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/67991c4d16db352a66014dcb8dfb4972.640x640x1.jpg',
#        'id': 4424735,
#        'lyrics_owner_id': 4801273,
#        'lyrics_state': 'complete',
#        'path': '/Kain-rivers-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/67991c4d16db352a66014dcb8dfb4972.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/67991c4d16db352a66014dcb8dfb4972.640x640x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Kain-rivers-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/1465098',
#         'header_image_url': 'https://images.genius.com/67991c4d16db352a66014dcb8dfb4972.640x640x1.jpg',
#         'id': 1465098,
#         'image_url': 'https://images.genius.com/67991c4d16db352a66014dcb8dfb4972.640x640x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Kain Rivers',
#         'url': 'https://genius.com/artists/Kain-rivers'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/4720637',
#        'full_title': "Chandelier by\xa0Dani\xa0Armstrong (Ft.\xa0Scott\xa0Bradlee's Postmodern Jukebox)",
#        'header_image_thumbnail_url': 'https://images.genius.com/ad5344013e227095519b28ccd6d369d9.224x224x1.jpg',
#        'header_image_url': 'https://images.genius.com/ad5344013e227095519b28ccd6d369d9.224x224x1.jpg',
#        'id': 4720637,
#        'lyrics_owner_id': 269182,
#        'lyrics_state': 'complete',
#        'path': '/Dani-armstrong-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/ad5344013e227095519b28ccd6d369d9.224x224x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/ad5344013e227095519b28ccd6d369d9.224x224x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': "Chandelier (Ft.\xa0Scott\xa0Bradlee's Postmodern Jukebox)",
#        'url': 'https://genius.com/Dani-armstrong-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/604859',
#         'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1582666308',
#         'id': 604859,
#         'image_url': 'https://assets.genius.com/images/default_avatar_300.png?1582666308',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Dani Armstrong',
#         'url': 'https://genius.com/artists/Dani-armstrong'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/4849124',
#        'full_title': 'Chandelier by\xa0Ali\xa0Brustofski',
#        'header_image_thumbnail_url': 'https://images.genius.com/72e5cff5860daf63b646c0ebb97a6414.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/72e5cff5860daf63b646c0ebb97a6414.500x500x1.jpg',
#        'id': 4849124,
#        'lyrics_owner_id': 8664184,
#        'lyrics_state': 'complete',
#        'path': '/Ali-brustofski-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/72e5cff5860daf63b646c0ebb97a6414.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/72e5cff5860daf63b646c0ebb97a6414.500x500x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Ali-brustofski-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/453382',
#         'header_image_url': 'https://images.genius.com/18b31aeeab692b473a4f1213c3cad2d1.300x300x1.jpg',
#         'id': 453382,
#         'image_url': 'https://images.genius.com/18b31aeeab692b473a4f1213c3cad2d1.300x300x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Ali Brustofski',
#         'url': 'https://genius.com/artists/Ali-brustofski'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/4932840',
#        'full_title': 'Chandelier by\xa0The\xa0Girl and the Dreamcatcher',
#        'header_image_thumbnail_url': 'https://images.genius.com/20f66eb6fec17afa986e666c31c82611.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/20f66eb6fec17afa986e666c31c82611.800x800x1.jpg',
#        'id': 4932840,
#        'lyrics_owner_id': 8293233,
#        'lyrics_state': 'complete',
#        'path': '/The-girl-and-the-dreamcatcher-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/20f66eb6fec17afa986e666c31c82611.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/20f66eb6fec17afa986e666c31c82611.800x800x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/The-girl-and-the-dreamcatcher-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/574055',
#         'header_image_url': 'https://images.genius.com/719a41a80d5f66b400528114ab287fee.1000x563x1.jpg',
#         'id': 574055,
#         'image_url': 'https://images.genius.com/20f66eb6fec17afa986e666c31c82611.800x800x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'The Girl and the Dreamcatcher',
#         'url': 'https://genius.com/artists/The-girl-and-the-dreamcatcher'}},
#       {'annotation_count': 0,
#        'api_path': '/songs/5279235',
#        'full_title': 'Chandelier by\xa0Charlotte\xa0Awbery',
#        'header_image_thumbnail_url': 'https://images.genius.com/94dec7444585cc7272ba07f13be2914b.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/94dec7444585cc7272ba07f13be2914b.400x400x1.jpg',
#        'id': 5279235,
#        'lyrics_owner_id': 7449414,
#        'lyrics_state': 'complete',
#        'path': '/Charlotte-awbery-chandelier-lyrics',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/94dec7444585cc7272ba07f13be2914b.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/94dec7444585cc7272ba07f13be2914b.400x400x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier',
#        'title_with_featured': 'Chandelier',
#        'url': 'https://genius.com/Charlotte-awbery-chandelier-lyrics',
#        'primary_artist': {'api_path': '/artists/2117491',
#         'header_image_url': 'https://images.genius.com/d963b2d869c3371a3813e03a460d94d5.355x198x1.png',
#         'id': 2117491,
#         'image_url': 'https://images.genius.com/94dec7444585cc7272ba07f13be2914b.400x400x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Charlotte Awbery',
#         'url': 'https://genius.com/artists/Charlotte-awbery'}}]},
#     {'relationship_type': 'remix_of', 'type': 'remix_of', 'songs': []},
#     {'relationship_type': 'remixed_by',
#      'type': 'remixed_by',
#      'songs': [{'annotation_count': 0,
#        'api_path': '/songs/2899874',
#        'full_title': 'Chandelier / Diamonds / Titanium (Medley) by\xa0Courtney\xa0Act',
#        'header_image_thumbnail_url': 'https://images.genius.com/85ab96cdacb9589631c50696a2a49089.300x300x1.jpg',
#        'header_image_url': 'https://images.genius.com/85ab96cdacb9589631c50696a2a49089.640x640x1.jpg',
#        'id': 2899874,
#        'lyrics_owner_id': 3390963,
#        'lyrics_state': 'complete',
#        'path': '/Courtney-act-chandelier-diamonds-titanium-medley-annotated',
#        'pyongs_count': None,
#        'song_art_image_thumbnail_url': 'https://images.genius.com/85ab96cdacb9589631c50696a2a49089.300x300x1.jpg',
#        'song_art_image_url': 'https://images.genius.com/85ab96cdacb9589631c50696a2a49089.640x640x1.jpg',
#        'stats': {'unreviewed_annotations': 0, 'hot': False},
#        'title': 'Chandelier / Diamonds / Titanium (Medley)',
#        'title_with_featured': 'Chandelier / Diamonds / Titanium (Medley)',
#        'url': 'https://genius.com/Courtney-act-chandelier-diamonds-titanium-medley-annotated',
#        'primary_artist': {'api_path': '/artists/405926',
#         'header_image_url': 'https://images.genius.com/992cf6968fb1c0c9c3a77b7ee264fde3.1000x265x1.jpg',
#         'id': 405926,
#         'image_url': 'https://images.genius.com/a5dc4da593f062781bf129d0b9eb9ccd.575x575x1.jpg',
#         'is_meme_verified': False,
#         'is_verified': False,
#         'name': 'Courtney Act',
#         'url': 'https://genius.com/artists/Courtney-act'}}]},
#     {'relationship_type': 'live_version_of',
#      'type': 'live_version_of',
#      'songs': []},
#     {'relationship_type': 'performed_live_as',
#      'type': 'performed_live_as',
#      'songs': []}],
#    'verified_annotations_by': [{'api_path': '/users/656681',
#      'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/849c5cdb861cdb5da53818855eda1381',
#        'bounding_box': {'width': 16, 'height': 16}},
#       'thumb': {'url': 'https://images.genius.com/avatars/thumb/849c5cdb861cdb5da53818855eda1381',
#        'bounding_box': {'width': 32, 'height': 32}},
#       'small': {'url': 'https://images.genius.com/avatars/small/849c5cdb861cdb5da53818855eda1381',
#        'bounding_box': {'width': 100, 'height': 100}},
#       'medium': {'url': 'https://images.genius.com/avatars/medium/849c5cdb861cdb5da53818855eda1381',
#        'bounding_box': {'width': 300, 'height': 400}}},
#      'header_image_url': 'https://images.genius.com/cb40ff6ba23119fdb3ec69073be7cf34.1000x427x1.jpg',
#      'human_readable_role_for_display': 'Verified Artist',
#      'id': 656681,
#      'iq': 6941,
#      'login': 'siamusic',
#      'name': 'Sia',
#      'role_for_display': 'verified_artist',
#      'url': 'https://genius.com/siamusic',
#      'current_user_metadata': {'permissions': [],
#       'excluded_permissions': ['follow'],
#       'interactions': {'following': False}}}],
#    'verified_contributors': [{'contributions': ['annotations'],
#      'artist': {'api_path': '/artists/16775',
#       'header_image_url': 'https://images.genius.com/cb40ff6ba23119fdb3ec69073be7cf34.1000x427x1.jpg',
#       'id': 16775,
#       'image_url': 'https://images.genius.com/6bcd2bd1708eeae7282400f1e4be633f.600x600x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': True,
#       'name': 'Sia',
#       'url': 'https://genius.com/artists/Sia',
#       'iq': 6941},
#      'user': {'api_path': '/users/656681',
#       'avatar': {'tiny': {'url': 'https://images.genius.com/avatars/tiny/849c5cdb861cdb5da53818855eda1381',
#         'bounding_box': {'width': 16, 'height': 16}},
#        'thumb': {'url': 'https://images.genius.com/avatars/thumb/849c5cdb861cdb5da53818855eda1381',
#         'bounding_box': {'width': 32, 'height': 32}},
#        'small': {'url': 'https://images.genius.com/avatars/small/849c5cdb861cdb5da53818855eda1381',
#         'bounding_box': {'width': 100, 'height': 100}},
#        'medium': {'url': 'https://images.genius.com/avatars/medium/849c5cdb861cdb5da53818855eda1381',
#         'bounding_box': {'width': 300, 'height': 400}}},
#       'header_image_url': 'https://images.genius.com/cb40ff6ba23119fdb3ec69073be7cf34.1000x427x1.jpg',
#       'human_readable_role_for_display': 'Verified Artist',
#       'id': 656681,
#       'iq': 6941,
#       'login': 'siamusic',
#       'name': 'Sia',
#       'role_for_display': 'verified_artist',
#       'url': 'https://genius.com/siamusic',
#       'current_user_metadata': {'permissions': [],
#        'excluded_permissions': ['follow'],
#        'interactions': {'following': False}}}}],
#    'verified_lyrics_by': [],
#    'writer_artists': [{'api_path': '/artists/154199',
#      'header_image_url': 'https://images.genius.com/bf7f5c1b74797d542e07b862e77dd8dd.600x402x1.jpg',
#      'id': 154199,
#      'image_url': 'https://images.genius.com/bf7f5c1b74797d542e07b862e77dd8dd.600x402x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Jesse Shatkin',
#      'url': 'https://genius.com/artists/Jesse-shatkin'},
#     {'api_path': '/artists/16775',
#      'header_image_url': 'https://images.genius.com/cb40ff6ba23119fdb3ec69073be7cf34.1000x427x1.jpg',
#      'id': 16775,
#      'image_url': 'https://images.genius.com/6bcd2bd1708eeae7282400f1e4be633f.600x600x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': True,
#      'name': 'Sia',
#      'url': 'https://genius.com/artists/Sia',
#      'iq': 6941}]}}}

# %% [markdown]
# While there is a lot of data contained in the response object, it seems that it contains neither the lyrics of the song, nor the Genius tags (Tags are the system by which Genius identifies genres and sub-genres of a song). This data is available on their website, but as of now, there is no support for it within the API. What we can do, however, is use the API as a springboard for more traditional web-scraping. The response includes a url for the song, under which the tag and lyric information are housed. We can first use the api to get a url, and then proceed to the url and scrape the data we desire.

# %%
json_object['response']['song']['path']
# Out:
# '/Sia-chandelier-lyrics'

# %% [markdown]
# Navigating to https://genuis.com/Sia-chandelier-lyrics gives us the page for the song, and we can see the lyrics displayed, as well as the 'tags' (read genres) near the bottom of the page. Now, we can use the BeautifulSoup python package to scrape the html of this page.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://genius.com' + json_object['response']['song']['path']
page = requests.get(url)

# %%
html = BeautifulSoup(page.text, 'html.parser')

line_collection = html.find('div',class_='lyrics').find('p').find_all('a')
text_collection = []
for line_object in line_collection:
    text_collection.append(line_object.text)
print(text_collection[:5])
# Out:
# ['[Verse 1]', "Party girls don't get hurt", "Can't feel anything, when will I learn?\nI push it down, push it down", 'I\'m the one "for a good time call"\nPhone\'s blowin\' up, ringin\' my doorbell\nI feel the love, feel the love', '1 2 3, 1 2 3, drink\n1 2 3, 1 2 3, drink\n1 2 3, 1 2 3, drink']

# %% [markdown]
# As you can see, now we have data containing all of the lyrics for this song, scraped from the site. Now to try and find the genre tags.

# %%
metadata = html.find_all('div',class_='metadata_with_icon_tags')
metadata
# Out:
# []

# %% [markdown]
# Unfortunately, it looks like that portion of the website is generated after the html is loaded, so while the browser can see it easily, our html files don't included. We have to change the way in which we recieved the html so that the our file is from after the javascript is run, and the data we want generated.

# %%
html
# Out:
# <!DOCTYPE html>
#
# <html class="snarly apple_music_player--enabled bagon_song_page--enabled song_stories_public_launch--enabled react_forums--disabled" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">
# <head>
# <base href="//genius.com/" target="_top"/>
# <script type="text/javascript">
# //<![CDATA[
#
#   var _sf_startpt=(new Date()).getTime();
#   if (window.performance && performance.mark) {
#     window.performance.mark('parse_start');
#   }
#
# //]]>
# </script>
# <title>Sia – Chandelier Lyrics | Genius Lyrics</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="app-id=709482991" name="apple-itunes-app"/>
# <link href="https://assets.genius.com/images/apple-touch-icon.png?1582907364" rel="apple-touch-icon"/>
# <link href="https://assets.genius.com/images/apple-touch-icon.png?1582907364" rel="apple-touch-icon"/>
# <!-- Mobile IE allows us to activate ClearType technology for smoothing fonts for easy reading -->
# <meta content="on" http-equiv="cleartype"/>
# <meta content="f63347d284f184b0" name="y_key"/>
# <meta content="Genius" property="og:site_name">
# <meta content="265539304824" property="fb:app_id">
# <meta content="308252472676410" property="fb:pages">
# <link href="https://genius.com/opensearch.xml" rel="search" title="Genius" type="application/opensearchdescription+xml"/>
# <script>
# !function(){if('PerformanceLongTaskTiming' in window){var g=window.__tti={e:[]};
# g.o=new PerformanceObserver(function(l){g.e=g.e.concat(l.getEntries())});
# g.o.observe({entryTypes:['longtask']})}}();
# </script>
# <script>
#   var CURRENT_USER = null;
#   var CANONICAL_DOMAIN = "genius.com";
#   var CANONICAL_DOMAIN_PARTS_LENGTH = 2;
#   var CURRENT_TAG = {"tag":{"always_allow_personal_annotation":null,"beefy":true,"created_at":"2013-11-01T11:44:18Z","deleted_at":null,"description":"Welcome to Pop Genius!  We break down the catchiest tunes of all time, from [Phil Spector drama](http://rock.rapgenius.com/Tina-turner-river-deep-mountain-high-lyrics) to [Madonna](http://rock.rapgenius.com/Madonna-like-a-virgin-lyrics) to [Lana](http://rock.rapgenius.com/Lana-del-rey-brooklyn-baby-lyrics).  Join the discussion in our [forum](http://rock.rapgenius.com/pop-team), and follow us on [Twitter](https://twitter.com/pop_genius) and [Facebook](https://www.facebook.com/thepopgenius).","designation":"featured_music","google_analytics_table_id":"ga:88194499","id":16,"image_url":"https://images.rapgenius.com/b9f560586012e6c61f052771eda6678d.300x300x1.jpg","languages_store":{},"logical_name":"pop","music":true,"name":"Pop Genius","slug":"pop","taggings_count":1956075,"twitter_name":"Pop_Genius","updated_at":"2020-02-29T11:21:04Z"}};
#   var TRACKING_DATA = {"Song ID":378195,"Title":"Chandelier","Primary Artist":"Sia","Primary Artist ID":16775,"Primary Album":"1000 Forms of Fear","Primary Album ID":104614,"Tag":"pop","Primary Tag":"pop","Primary Tag ID":16,"Music?":true,"Annotatable Type":"Song","Annotatable ID":378195,"featured_video":true,"cohort_ids":[],"has_verified_callout":true,"has_featured_annotation":true,"created_at":"2014-03-10T19:23:47Z","created_month":"2014-03-01","created_year":2014,"song_tier":"C","Has Recirculated Articles":false,"Lyrics Language":"en","Has Song Story":false,"Song Story ID":null,"Has Apple Match":true,"Release Date":"2014-03-17","NRM Tier":null,"NRM Target Date":null,"Has Description":true,"Has Youtube URL":true,"Has Translation Q&A":false,"Comment Count":80};
#   var VALID_SUBDOMAINS = ["non-music","rap","rock","country","r-b","pop"];
#   var EMBEDLY_KEY = "fc778e44915911e088ae4040f9f86dcd";
#   var MOBILE_DEVICE = false;
#   var APP_CONFIG = {"env":"production","api_root_url":"/api","transform_domain":"transform.genius.com","facebook_app_id":"265539304824","facebook_opengraph_api_version":"3.2","pusher_app_key":"6d893fcc6a0c695853ac","embedly_key":"fc778e44915911e088ae4040f9f86dcd","a9_pub_id":"3459","app_store_url":"https://itunes.apple.com/us/app/genius-by-rap-genius-search/id709482991?ls=1&mt=8","play_store_url":"https://play.google.com/store/apps/details?id=com.genius.android","soundcloud_client_id":"632c544d1c382f82526f369877aab5c0","annotator_context_length":32,"comment_reasons":[{"_type":"comment_reason","context_url":"https://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"R","handle":"Restates the line","id":1,"name":"restates-the-line","raw_name":"restates the line","requires_body":false,"slug":"restates_the_line"},{"_type":"comment_reason","context_url":"https://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"S","handle":"It’s a stretch","id":2,"name":"its-a-stretch","raw_name":"it’s a stretch","requires_body":false,"slug":"its_a_stretch"},{"_type":"comment_reason","context_url":"https://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"M","handle":"Missing something","id":3,"name":"missing-something","raw_name":"missing something","requires_body":false,"slug":"missing_something"},{"_type":"comment_reason","context_url":"https://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"…","handle":"Other","id":4,"name":"other","raw_name":"other","requires_body":true,"slug":"other"}],"comment_reasons_help_url":"https://genius.com/8846441/Genius-how-genius-works/More-on-annotations","filepicker_api_key":"Ar03MDs73TQm241ZgLwfjz","filepicker_policy":"eyJleHBpcnkiOjIzNTEwOTE1NTgsImNhbGwiOlsicGljayIsInJlYWQiLCJzdG9yZSIsInN0YXQiLCJjb252ZXJ0Il19","filepicker_signature":"68597b455e6c09bce0bfd73f758e299c95d49a5d5c8e808aaf4877da7801c4da","filepicker_s3_image_bucket":"filepicker-images-rapgenius","available_roles":["moderator","mega_boss","in_house_staff","verified_artist","meme_artist","engineer","editor","educator","staff","whitehat","tech_liaison","mediator"],"canonical_domain":"genius.com","enable_angular_debug":false,"fact_track_launch_article_url":"https://genius.com/a/genius-and-spotify-together","user_authority_roles":["moderator","editor","mediator"],"user_verification_roles":["community_artist","verified_artist","meme_artist"],"user_vote_types_for_delete":["votes","upvotes","downvotes"],"brightcove_account_id":"4863540648001","mixpanel_delayed_events_timeout":"86400","unreviewed_annotation_tooltip_info_url":"https://genius.com/8846524/Genius-how-genius-works/More-on-editorial-review","video_placements":{"desktop_song_page":[{"name":"sidebar","min_relevance":"high","fringe_min_relevance":"low","max_videos":0},{"name":"sidebar_thumb","min_relevance":"medium","fringe_min_relevance":"low","max_videos":0},{"name":"recirculated","min_relevance":"low","max_videos":3}],"mobile_song_page":[{"name":"footer","min_relevance":"medium","max_videos":1},{"name":"recirculated","min_relevance":"low","max_videos":3}],"desktop_artist_page":[{"name":"sidebar","min_relevance":"medium","fringe_min_relevance":"low","max_videos":2}],"mobile_artist_page":[{"name":"carousel","min_relevance":"medium","fringe_min_relevance":"low","max_videos":5}],"amp_song_page":[{"name":"footer","min_relevance":"medium","max_videos":1}],"amp_video_page":[{"name":"related","min_relevance":"low","max_videos":8}],"desktop_video_page":[{"name":"series_related","min_relevance":"low","max_videos":8,"series":true},{"name":"related","min_relevance":"low","max_videos":8}],"desktop_article_page":[{"name":"carousel","min_relevance":"low","max_videos":5}],"mobile_article_page":[{"name":"carousel","min_relevance":"low","max_videos":5}],"desktop_album_page":[{"name":"sidebar","min_relevance":"medium","fringe_min_relevance":"low","max_videos":1}],"amp_album_page ...
#   var SESSION_CONFIG = {"current_user":null,"taboola_enabled":false,"fringe_enabled":true,"log_client_metrics":false,"show_ads":true,"ccpaEnabled":true};
#   var AD_CONFIG = {"ad_placements":{"amp_article_sticky":{"sizes":[[300,50],[320,50]],"a9":true,"kv":{"is_atf":false}},"amp_article_footer":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_mw_article_footer_prebid"}}]},"amp_album_sticky":{"sizes":[[320,50]],"a9":true,"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_mw_album_sticky_prebid"}}]},"amp_album_footer":{"sizes":[[300,250]],"a9":true,"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_mw_album_footer_prebid"}}]},"amp_song_annotation":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294868"}},{"bidder":"ix","params":{"id":10,"siteID":194719}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613918"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_annotation_prebid"}}]},"amp_song_below_player":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_song_below_player_prebid"}}]},"amp_song_below_song_bio":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294916"}},{"bidder":"ix","params":{"id":8,"siteID":194716}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613910"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_below_song_bio_prebid"}}]},"amp_song_leaderboard":{"sizes":[[320,50]],"a9":true,"kv":{"is_atf":true},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"13937404"}},{"bidder":"ix","params":{"id":25,"siteID":300787}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"1051268"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_leaderboard_prebid"}}]},"amp_song_medium1":{"sizes":[[300,250],[320,480]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294891"}},{"bidder":"ix","params":{"id":1,"siteID":194712}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613900"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium1_prebid"}}]},"amp_song_medium2":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294897"}},{"bidder":"ix","params":{"id":5,"siteID":194713}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613902"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium2_prebid"}}]},"amp_song_medium3":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294900"}},{"bidder":"ix","params":{"id":6,"siteID":194714}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613906"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium3_prebid"}}]},"amp_song_medium_footer":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294876"}},{"bidder":"ix","params":{"id":7,"siteID":194715}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613908"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium_footer_prebid"}}]},"amp_song_q_and_a":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294908"}},{"bidder":"ix","params":{"id":11,"siteID":194720}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613920"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_q_and_a_prebid"}}]},"amp_song_sticky":{"sizes":[[300,50],[320,50]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294881"}},{"bidder":"ix","params":{"id":3,"siteID":194711}},{"bidder":" ...
#   var ANALYTICS_CONFIG = {"enabled":true,"mixpanel_enabled":true,"comscore_client_id":"17151659","quantcast_account":"p-f3CPQ6vHckedE","librato_web_client_host":"librato-collector.genius.com"}
#   var TOP_LEVEL_BLOCK_CONTAINERS = ["address","article","aside","blockquote","div","dl","fieldset","footer","form","h1","h2","h3","h4","h5","h6","header","menu","nav","ol","p","pre","section","table","ul"];
#   var TOP_LEVEL_STANDALONE_BLOCKS = ["img","hr"];
# </script>
# <script async="" src="https://www.youtube.com/iframe_api"></script>
# <script defer="" src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.4/jquery.min.js"></script>
# <script>
#   window['Genius.cmp'] = window['Genius.cmp'] || [];
# </script>
# <!--sse-->
# <script>window['Genius.ads'] = window['Genius.ads'] || [];</script>
# <script defer="true" src="https://assets.genius.com/javascripts/compiled/ads-aa8ed11754b869a578b1.js" type="text/javascript"></script>
# <script async="true" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript"></script>
# <script>
# !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
# </script>
# <script>
#     window['Genius.ads'].push(function(ads) {
#       var config = {"ad_placements":{"amp_article_sticky":{"sizes":[[300,50],[320,50]],"a9":true,"kv":{"is_atf":false}},"amp_article_footer":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_mw_article_footer_prebid"}}]},"amp_album_sticky":{"sizes":[[320,50]],"a9":true,"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_mw_album_sticky_prebid"}}]},"amp_album_footer":{"sizes":[[300,250]],"a9":true,"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_mw_album_footer_prebid"}}]},"amp_song_annotation":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294868"}},{"bidder":"ix","params":{"id":10,"siteID":194719}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613918"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_annotation_prebid"}}]},"amp_song_below_player":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_song_below_player_prebid"}}]},"amp_song_below_song_bio":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294916"}},{"bidder":"ix","params":{"id":8,"siteID":194716}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613910"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_below_song_bio_prebid"}}]},"amp_song_leaderboard":{"sizes":[[320,50]],"a9":true,"kv":{"is_atf":true},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"13937404"}},{"bidder":"ix","params":{"id":25,"siteID":300787}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"1051268"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_leaderboard_prebid"}}]},"amp_song_medium1":{"sizes":[[300,250],[320,480]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294891"}},{"bidder":"ix","params":{"id":1,"siteID":194712}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613900"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium1_prebid"}}]},"amp_song_medium2":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294897"}},{"bidder":"ix","params":{"id":5,"siteID":194713}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613902"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium2_prebid"}}]},"amp_song_medium3":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294900"}},{"bidder":"ix","params":{"id":6,"siteID":194714}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613906"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium3_prebid"}}]},"amp_song_medium_footer":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294876"}},{"bidder":"ix","params":{"id":7,"siteID":194715}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613908"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium_footer_prebid"}}]},"amp_song_q_and_a":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294908"}},{"bidder":"ix","params":{"id":11,"siteID":194720}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613920"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_q_and_a_prebid"}}]},"amp_song_sticky":{"sizes":[[300,50],[320,50]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294881"}},{"bidder":"ix","params":{"id":3,"siteID":194711}},{"bidder": ...
#       var targeting_list = [{"name":"song_id","values":["378195"]},{"name":"song_title","values":["Chandelier"]},{"name":"artist_id","values":["16775"]},{"name":"artist_name","values":["Sia"]},{"name":"is_explicit","values":["false"]},{"name":"pageviews","values":["1580652"]},{"name":"primary_tag_id","values":["16"]},{"name":"tag_id","values":["73","435","352","72","16"]},{"name":"song_tier","values":["C"]},{"name":"topic","values":[]},{"name":"has_song_story","values":["false"]},{"name":"in_top_10","values":["false"]},{"name":"artist_in_top_10","values":["false"]},{"name":"album_in_top_10","values":["false"]},{"name":"new_release","values":["false"]},{"name":"release_month","values":["201403"]},{"name":"release_year","values":["2014"]},{"name":"release_decade","values":["2010"]},{"name":"in_top_10_rap","values":["false"]},{"name":"in_top_10_rock","values":["false"]},{"name":"in_top_10_country","values":["false"]},{"name":"in_top_10_r_and_b","values":["false"]},{"name":"in_top_10_pop","values":["false"]},{"name":"template","values":["song"]},{"name":"environment","values":["production"]},{"name":"platform","values":["web"]}];
#       var initial_units = ["desktop_song_about_leaderboard","desktop_song_about_sidebar","desktop_song_comments_leaderboard","desktop_song_comments_sidebar","desktop_song_inread","desktop_song_inread2","desktop_song_inread3","desktop_song_leaderboard","desktop_song_lyrics_sidebar","desktop_song_lyrics_footer","desktop_song_marquee","desktop_song_medium1","desktop_song_sidebar_top"];
#       var targeting = {};
#       targeting_list.forEach(function(pair) {
#         targeting[pair.name] = pair.values;
#       });
#       var initial_last_reset_at = undefined || Date.now();
#
#       ads.initialize({config: config, targeting: targeting, initial_units: initial_units, initial_last_reset_at: initial_last_reset_at});
#
#     });
#   </script>
# <script async="" src="https://cdn.adsafeprotected.com/iasPET.1.js"></script>
# <!--/sse-->
# <link href="https://assets.genius.com/stylesheets/compiled/bagon_desktop-c38b6713ec8f79aa5f6f15ade0635b79.css" media="screen" rel="stylesheet" type="text/css">
# <link as="script" href="https://assets.genius.com/javascripts/compiled/bagon_desktop-6287f79e10a22910b6ce.js" rel="preload"/><script defer="true" src="https://assets.genius.com/javascripts/compiled/bagon_desktop-6287f79e10a22910b6ce.js" type="text/javascript"></script>
# <style>
#   @font-face {
#     font-family: 'Programme';
#     src: url(data:font/woff2;base64,...) format('woff2'),
#       url(https://assets.genius.com/fonts/programme_bold.woff?1582907364) format('woff');
#     font-style: normal;
#     font-weight: bold;
#   }
#
#   @font-face {
#     font-family: 'Programme';
#     src: url(https://assets.genius.com/fonts/programme_normal.woff2?1582907364) format('woff2'),
#       url(https://assets.genius.com/fonts/programme_normal.woff?1582907364) format('woff');
#     font-style: normal;
#     font-weight: normal;
#   }
#
#   @font-face {
#     font-family: 'Programme';
#     src: url(https://assets.genius.com/fonts/programme_normal_italic.woff2?1582907364) format('woff2'),
#       url(https://assets.genius.com/fonts/programme_normal_italic.woff?1582907364) format('woff');
#     font-style: italic;
#     font-weight: normal;
#   }
#
#   @font-face {
#     font-family: 'Programme';
#     src: url(https://assets.genius.com/fonts/programme_light.woff2?1582907364) format('woff2'),
#       url(https://assets.genius.com/fonts/programme_light.woff?1582907364) format('woff');
#     font-style: normal;
#     font-weight: 100;
#   }
#
#   @font-face {
#     font-family: 'Programme';
#     src: url(https://assets.genius.com/fonts/programme_light_italic.woff2?1582907364) format('woff2'),
#       url(https://assets.genius.com/fonts/programme_light_italic.woff?1582907364) format('woff');
#     font-style: italic;
#     font-weight: 100;
#   }
# </style>
# <meta content="https://genius.com/Sia-chandelier-lyrics" property="og:url">
# <meta content="music.song" property="og:type"/>
# <meta content="Sia – Chandelier" property="og:title"/>
# <meta content="“Chandelier” was released as the lead single from Sia’s sixth studio album, 1000 Forms Of Fear. Despite its soaring melody, the song has a sad theme describing the life of a “party" property="og:description"/>
# <meta content="https://images.genius.com/4b681dde97d03ce4a93fb1515fb7219d.600x600x1.jpg" property="og:image"/>
# <meta content="https://genius.com/Sia-chandelier-lyrics" property="twitter:url"/>
# <meta content="music.song" property="twitter:type"/>
# <meta content="Sia – Chandelier" property="twitter:title"/>
# <meta content="“Chandelier” was released as the lead single from Sia’s sixth studio album, 1000 Forms Of Fear. Despite its soaring melody, the song has a sad theme describing the life of a “party" property="twitter:description"/>
# <meta content="https://images.genius.com/4b681dde97d03ce4a93fb1515fb7219d.600x600x1.jpg" property="twitter:image"/>
# <meta content="@Genius" property="twitter:site"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Genius" property="twitter:app:name:iphone"/>
# <meta content="709482991" property="twitter:app:id:iphone"/>
# <meta content="genius://songs/378195" property="twitter:app:url:iphone"/>
# <meta content="Chandelier Lyrics: Party girls don't get hurt / Can't feel anything, when will I learn? / I push it down, push it down / I'm the one &quot;for a good time call&quot; / Phone's blowin' up, ringin' my doorbell" name="description"/>
# <link href="ios-app://709482991/genius/songs/378195" rel="alternate"/>
# <meta content="/songs/378195" name="newrelic-resource-path"/>
# <link href="https://genius.com/Sia-chandelier-lyrics" rel="canonical"/>
# <link href="https://genius.com/amp/Sia-chandelier-lyrics" rel="amphtml"/>
# <script type="text/javascript">
#   var _qevents = _qevents || [];
#   (function() {
#     var elem = document.createElement('script');
#     elem.src = (document.location.protocol == 'https:' ? 'https://secure' : 'http://edge') + '.quantserve.com/quant.js';
#     elem.async = true;
#     elem.type = 'text/javascript';
#     var scpt = document.getElementsByTagName('script')[0];
#     scpt.parentNode.insertBefore(elem, scpt);
#   })();
# </script>
# <script type="text/javascript">
#   window.ga = window.ga || function() {
#     (window.ga.q = window.ga.q || []).push(arguments);
#   };
#
#
#     (function(g, e, n, i, u, s) {
#       g['GoogleAnalyticsObject'] = 'ga';
#       g.ga.l = Date.now();
#       u = e.createElement(n);
#       s = e.getElementsByTagName(n)[0];
#       u.async = true;
#       u.src = i;
#       s.parentNode.insertBefore(u, s);
#     })(window, document, 'script', 'https://www.google-analytics.com/analytics.js');
#
#     ga('create', "UA-10346621-1", 'auto', {'useAmpClientId': true});
#     ga('set', 'dimension1', "false");
#     ga('set', 'dimension2', "songs#show");
#     ga('set', 'dimension3', "pop");
#     ga('set', 'dimension4', "true");
#     ga('set', 'dimension5', 'false');
#     ga('set', 'dimension6', 'none');
#     ga('send', 'pageview');
#
# </script>
# <script>
#   let fullstory_segment;
#   try { fullstory_segment = localStorage.getItem('genius_fullstory_segment'); } catch (e) {}
#
#   if (typeof(fullstory_segment) === 'string') {
#     fullstory_segment = Number(fullstory_segment);
#   } else {
#     fullstory_segment = Math.random();
#     try { localStorage.setItem('genius_fullstory_segment', fullstory_segment); } catch (e) {}
#   }
#
#   if (fullstory_segment < 0.004) {
#     window['_fs_debug'] = false;
# window['_fs_host'] = 'fullstory.com';
# window['_fs_script'] = 'edge.fullstory.com/s/fs.js';
# window['_fs_org'] = 'AGFQ9';
# window['_fs_namespace'] = 'FS';
# (function(m,n,e,t,l,o,g,y){
#   if (e in m) {if(m.console && m.console.log) { m.console.log('FullStory namespace conflict. Please set window["_fs_namespace"].');} return;}
#   g=m[e]=function(a,b,s){g.q?g.q.push([a,b,s]):g._api(a,b,s);};g.q=[];
#   o=n.createElement(t);o.async=1;o.crossOrigin='anonymous';o.src='https://'+_fs_script;
#   y=n.getElementsByTagName(t)[0];y.parentNode.insertBefore(o,y);
#   g.identify=function(i,v,s){g(l,{uid:i},s);if(v)g(l,v,s)};g.setUserVars=function(v,s){g(l,v,s)};g.event=function(i,v,s){g('event',{n:i,p:v},s)};
#   g.shutdown=function(){g("rec",!1)};g.restart=function(){g("rec",!0)};
#   g.log = function(a,b) { g("log", [a,b]) };
#   g.consent=function(a){g("consent",!arguments.length||a)};
#   g.identifyAccount=function(i,v){o='account';v=v||{};v.acctId=i;g(o,v)};
#   g.clearUserCookie=function(){};
# })(window,document,window['_fs_namespace'],'script','user');
#
#     if (CURRENT_USER) {
#       FS.identify('user:' + CURRENT_USER.id, {
#         displayName: CURRENT_USER.login,
#         contrib_bool: CURRENT_USER.is_contrib,
#         editor_bool: CURRENT_USER.is_editor,
#       });
#     } else {
#       FS.identify(false);
#     }
#
#     const datetime_regex = /^\d{4}-\d\d-\d\d(T\d\d:\d\d(:\d\d(\.\d+)?)?(Z|[-+]\d\d:\d\d))?$/;
#
#     FS.from_mixpanel = (event, properties) => {
#       FS.event(event,
#         _(properties).
#           mapKeys((value, key) => _.snakeCase(key)).
#           mapValues((value) =>
#             typeof(value) === 'string' && datetime_regex.test(value) ? new Date(value) : value
#           ).value()
#       );
#     }
#   }
# </script>
# <meta content="{&quot;chartbeat&quot;:{&quot;authors&quot;:&quot;Sia&quot;,&quot;sections&quot;:&quot;songs,tag:r-b,tag:pop&quot;,&quot;title&quot;:&quot;Sia – Chandelier Lyrics | Genius Lyrics&quot;},&quot;controller_and_action&quot;:&quot;songs#show&quot;,&quot;dmp_data_layer&quot;:{&quot;page&quot;:{&quot;type&quot;:&quot;song&quot;,&quot;artists&quot;:[&quot;Sia&quot;],&quot;artist_ids&quot;:[&quot;[16775]&quot;],&quot;albums&quot;:[&quot;1000 Forms of Fear&quot;,&quot;Spotify Sessions&quot;,&quot;NOW That’s What I Call Music! 88 [UK]&quot;,&quot;Fremde Zungen&quot;,&quot;MuchDance 2015&quot;],&quot;album_ids&quot;:[&quot;[104614]&quot;,&quot;[362590]&quot;,&quot;[366657]&quot;,&quot;[461698]&quot;,&quot;[499393]&quot;],&quot;genres&quot;:[&quot;Ballad&quot;,&quot;Reggae&quot;,&quot;R&amp;B Genius&quot;,&quot;Electro-Pop&quot;,&quot;Pop Genius&quot;],&quot;genre_ids&quot;:[&quot;[73]&quot;,&quot;[435]&quot;,&quot;[352]&quot;,&quot;[72]&quot;,&quot;[16]&quot;],&quot;in_top_10&quot;:false,&quot;artist_in_top_10&quot;:false,&quot;album_in_top_10&quot;:false,&quot;new_release&quot;:false,&quot;release_month&quot;:&quot;201403&quot;,&quot;release_year&quot;:2014,&quot;release_decade&quot;:2010}},&quot;header_bid_placements&quot;:[[&quot;desktop_song_leaderboard&quot;,&quot;desktop_song_leaderboard&quot;],[&quot;desktop_song_sidebar_top&quot;,&quot;desktop_song_sidebar_top&quot;],[&quot;desktop_song_medium1&quot;,&quot;desktop_song_medium1&quot;]],&quot;initial_ad_units&quot;:[&quot;desktop_song_about_leaderboard&quot;,&quot;desktop_song_about_sidebar&quot;,&quot;desktop_song_comments_leaderboard&quot;,&quot;desktop_song_comments_sidebar&quot;,&quot;desktop_song_inread&quot;,&quot;desktop_song_inread2&quot;,&quot;desktop_song_inread3&quot;,&quot;desktop_song_leaderboard&quot;,&quot;desktop_song_lyrics_sidebar&quot;,&quot;desktop_song_lyrics_footer&quot;,&quot;desktop_song_marquee&quot;,&quot;desktop_song_medium1&quot;,&quot;desktop_song_sidebar_top&quot;],&quot;page_type&quot;:&quot;song&quot;,&quot;path&quot;:&quot;/Sia-chandelier-lyrics&quot;,&quot;probably_spam&quot;:false,&quot;title&quot;:&quot;Sia – Chandelier Lyrics | Genius Lyrics&quot;,&quot;tracking_data&quot;:[{&quot;key&quot;:&quot;Song ID&quot;,&quot;value&quot;:378195},{&quot;key&quot;:&quot;Title&quot;,&quot;value&quot;:&quot;Chandelier&quot;},{&quot;key&quot;:&quot;Primary Artist&quot;,&quot;value&quot;:&quot;Sia&quot;},{&quot;key&quot;:&quot;Primary Artist ID&quot;,&quot;value&quot;:16775},{&quot;key&quot;:&quot;Primary Album&quot;,&quot;value&quot;:&quot;1000 Forms of Fear&quot;},{&quot;key&quot;:&quot;Primary Album ID&quot;,&quot;value&quot;:104614},{&quot;key&quot;:&quot;Tag&quot;,&quot;value&quot;:&quot;pop&quot;},{&quot;key&quot;:&quot;Primary Tag&quot;,&quot;value&quot;:&quot;pop&quot;},{&quot;key&quot;:&quot;Primary Tag ID&quot;,&quot;value&quot;:16},{&quot;key&quot;:&quot;Music?&quot;,&quot;value&quot;:true},{&quot;key&quot;:&quot;Annotatable Type&quot;,&quot;value&quot;:&quot;Song&quot;},{&quot;key&quot;:&quot;Annotatable ID&quot;,&quot;value&quot;:378195},{&quot;key&quot;:&quot;featured_video&quot;,&quot;value&quot;:true},{&quot;key&quot;:&quot;cohort_ids&quot;,&quot;value&quot;:[]},{&quot;key&quot;:&quot;has_verified_callout&quot;,&quot;value&quot;:true},{&quot;key&quot;:&quot;has_featured_annotation&quot;,&quot;value&quot;:true},{&quot;key&quot;:&quot;created_at&quot;,&quot;value&quot;:&quot;2014-03-10T19:23:47Z&quot;},{&quot;key&quot;:&quot;created_month&quot;,&quot;value&quot;:&quot;2014-03-01&quot;},{&quot;key&quot;:&quot;created_year&quot;,&quot;value&quot;:2014},{&quot;key&quot;:&quot;song_tier&quot;,&quot;value&quot;:&quot;C&quot;},{&quot;key&quot;:&quot;Has Recirculated Articles&quot;,&quot;value&quot;:false},{&quot;key&quot;:&quot;Lyrics Language&quot;,&quot;value&quot;:&quot;en&quot;},{&quot;key&quot;:&quot;Has Song Story&quot;,&quot;value&quot;:false},{&quot;key&quot;:&quot;Song Story ID&quot;,&quot;value&quot;:null},{&quot;key&quot;:&quot; ...
# </meta></link></meta></meta></meta></head>
# <body class="act-show cont-songs snarly">
# <preload ng-non-bindable=""><preload-content data-preload_data='{"iq_by_event_type":{"accepted_a_lyrics_edit":3.0,"annotation_downvote_by_contrib":-1.0,"annotation_downvote_by_default":-1.0,"annotation_downvote_by_editor":-1.0,"annotation_downvote_by_high_iq_user":-1.0,"annotation_downvote_by_moderator":-1.0,"annotation_upvote_by_contrib":4.0,"annotation_upvote_by_default":2.0,"annotation_upvote_by_editor":6.0,"annotation_upvote_by_high_iq_user":4.0,"annotation_upvote_by_moderator":10.0,"answer_downvote_by_contrib":-1.0,"answer_downvote_by_default":-1.0,"answer_downvote_by_editor":-1.0,"answer_downvote_by_high_iq_user":-1.0,"answer_downvote_by_moderator":-1.0,"answered_a_question":5.0,"answered_a_question_meme":25.0,"answered_a_question_verified":10.0,"answer_upvote_by_contrib":4.0,"answer_upvote_by_default":2.0,"answer_upvote_by_editor":6.0,"answer_upvote_by_high_iq_user":4.0,"answer_upvote_by_moderator":10.0,"archived_a_question":1.0,"article_downvote":-1.0,"article_upvote":1.0,"asked_a_question":1.0,"auto_accepted_explanation":15.0,"comment_downvote":-0.5,"comment_upvote":0.5,"created_a_lyrics_edit":2.0,"created_a_real_song":40.0,"created_a_song":5.0,"forum_post_downvote":-0.5,"forum_post_upvote":0.5,"historical_you_published_a_song":60.0,"metadata_update_or_addition":2.0,"pending_explanation":5.0,"pinned_a_question_not_your_own":2.0,"question_downvote":-2.0,"question_upvote":2.0,"rejected_a_lyrics_edit":2.0,"song_metadata_update_or_addition":2.0,"song_pageviews_1000":25.0,"song_pageviews_10000":50.0,"song_pageviews_100000":125.0,"song_pageviews_1000000":500.0,"song_pageviews_2500":30.0,"song_pageviews_25000":75.0,"song_pageviews_250000":150.0,"song_pageviews_2500000":1000.0,"song_pageviews_500":20.0,"song_pageviews_5000":35.0,"song_pageviews_50000":100.0,"song_pageviews_500000":200.0,"song_pageviews_5000000":2000.0,"suggestion_downvote_by_contrib":-1.0,"suggestion_downvote_by_default":-0.5,"suggestion_downvote_by_editor":-1.0,"suggestion_downvote_by_high_iq_user":-1.0,"suggestion_downvote_by_moderator":-1.0,"suggestion_upvote_by_contrib":2.0,"suggestion_upvote_by_default":1.0,"suggestion_upvote_by_editor":3.0,"suggestion_upvote_by_high_iq_user":2.0,"suggestion_upvote_by_moderator":4.0,"verified_explanation_by_meme":100.0,"verified_explanation_by_non_meme":15.0,"verified_lyrics_by_meme_featured":50.0,"verified_lyrics_by_meme_primary":75.0,"verified_lyrics_by_meme_writer":75.0,"verified_lyrics_by_non_meme_featured":10.0,"verified_lyrics_by_non_meme_primary":15.0,"verified_lyrics_by_non_meme_writer":15.0,"you_accepted_a_comment":6.0,"you_accepted_an_annotation":10.0,"you_added_a_photo":100.0,"you_archived_a_comment":2.0,"you_deleted_an_annotation":5.0,"you_incorporated_an_annotation":5.0,"you_integrated_a_comment":2.0,"you_linked_an_identity":100.0,"you_merged_an_annotation_edit":4.0,"you_published_a_song":5.0,"your_annotation_accepted":10.0,"your_annotation_edit_merged":5.0,"your_annotation_edit_rejected":-0.5,"your_annotation_incorporated":15.0,"your_annotation_rejected":0.0,"your_annotation_was_cosigned_by_community_verified":2.0,"your_annotation_was_cosigned_by_meme":50.0,"your_annotation_was_cosigned_by_verified_verified":20.0,"your_answer_cleared":-5.0,"your_answer_pinned":5.0,"your_comment_accepted":2.0,"your_comment_archived":0.0,"your_comment_integrated":2.0,"your_comment_rejected":-0.5,"you_rejected_a_comment":2.0,"you_rejected_an_annotation":2.0,"you_rejected_an_annotation_edit":2.0,"your_lyrics_edit_accepted":3.0,"your_lyrics_edit_rejected":-2.0,"your_question_answered":4.0,"your_question_archived":-1.0,"your_question_pinned":5.0}}'></preload-content></preload>
# <marquee-ad name="desktop_song_marquee"></marquee-ad>
# <div class="header" click-outside="close_mobile_subnav_menu()" ng-controller="HeaderCtrl as header_ctrl">
# <global-message ng-cloak="" ng-if="header_ctrl.cloudflare_error">
#     {{:: 'cloud_flare_always_on_short_message' | i18n }}
#     <br/>Check <a href="https://twitter.com/genius" target="_blank">@genius</a> for updates. We'll have things fixed soon.
#   </global-message>
# <div class="header-primary active">
# <div class="header-expand_nav_menu" ng-click="toggle_mobile_subnav_menu()"><div class="header-expand_nav_menu-contents"></div></div>
# <div class="logo_container">
# <a class="logo_link" href="https://genius.com/">GENIUS</a>
# </div>
# <header-actions></header-actions>
# </div>
# <search-form search-style="header"></search-form>
# <ul class="header-nav_menu" ng-class="{'header-nav_menu--visible': mobile_subnav_menu_open}">
# <div ng-cloak="">
# <header-menu-item class="header-nav_menu--hide_when_expand_menu_is_not_available" name="Home" url="https://genius.com/"></header-menu-item>
# <header-menu-item name="Featured" url="https://genius.com/#featured-stories"></header-menu-item>
# <header-menu-item name="Charts" url="https://genius.com/#top-songs"></header-menu-item>
# <header-menu-item name="Videos" url="https://genius.com/#videos"></header-menu-item>
# <header-menu-item name="Community" url="https://genius.com/#community"></header-menu-item>
# <span class="nav_menu-item nav_menu-item--separator">|</span>
# <header-menu-item name="Shop" url="https://shop.genius.com/"></header-menu-item>
# <span class="nav_menu-item nav_menu-item--separator">|</span>
# <li class="nav_menu-item">
# <a class="nav_menu-link nav_menu-link--facebook" href="https://www.facebook.com/geniusdotcom/" target="_blank">
# <svg class="inline_icon" src="facebook.svg"></svg>
# <span class="nav_menu-link-social_text">Facebook</span>
# </a>
# </li>
# <li class="nav_menu-item">
# <a class="nav_menu-link" href="https://twitter.com/Genius" target="_blank">
# <svg class="inline_icon" src="twitter.svg"></svg>
# <span class="nav_menu-link-social_text">Twitter</span>
# </a>
# </li>
# <li class="nav_menu-item">
# <a class="nav_menu-link" href="https://www.instagram.com/genius/" target="_blank">
# <svg class="inline_icon" src="instagram.svg"></svg>
# <span class="nav_menu-link-social_text">Instagram</span>
# </a>
# </li>
# <li class="nav_menu-item">
# <a class="nav_menu-link nav_menu-link--no_right_padding" href="https://www.youtube.com/genius" target="_blank">
# <svg class="inline_icon nav_menu-link-youtube_icon" src="youtube.svg"></svg>
# <span class="nav_menu-link-social_text">Youtube</span>
# </a>
# </li>
# </div>
# </ul>
# </div>
# <div class="global_messages">
# <flash-messages></flash-messages>
# </div>
# <script type="application/ld+json">
#         {"@context":"http://schema.org","@type":"MusicRecording","byArtist":{"@context":"http://schema.org","@type":"MusicGroup","name":"Sia","url":"https://genius.com/artists/Sia","description":"Sia Kate Isobelle Furler (born December 18, 1975), popularly known as Sia, is an Australian pop singer and songwriter. She is also part of the supergroup, LSD alongside, British","image":"https://images.genius.com/6bcd2bd1708eeae7282400f1e4be633f.600x600x1.jpg"},"image":"https://images.genius.com/4b681dde97d03ce4a93fb1515fb7219d.600x600x1.jpg","inAlbum":[{"@context":"http://schema.org","@type":"MusicAlbum","byArtist":{"@context":"http://schema.org","@type":"MusicGroup","name":"Sia","url":"https://genius.com/artists/Sia","description":"Sia Kate Isobelle Furler (born December 18, 1975), popularly known as Sia, is an Australian pop singer and songwriter. She is also part of the supergroup, LSD alongside, British","image":"https://images.genius.com/6bcd2bd1708eeae7282400f1e4be633f.600x600x1.jpg"},"image":"https://images.genius.com/0a2dfec3681e8b19da8c37dd7ecf193c.1000x1000x1.jpg","name":"1000 Forms of Fear","url":"https://genius.com/albums/Sia/1000-forms-of-fear","datePublished":"2014-07-04","numTracks":12},{"@context":"http://schema.org","@type":"MusicAlbum","byArtist":{"@context":"http://schema.org","@type":"MusicGroup","name":"Sia","url":"https://genius.com/artists/Sia","description":"Sia Kate Isobelle Furler (born December 18, 1975), popularly known as Sia, is an Australian pop singer and songwriter. She is also part of the supergroup, LSD alongside, British","image":"https://images.genius.com/6bcd2bd1708eeae7282400f1e4be633f.600x600x1.jpg"},"image":"https://images.genius.com/ad2d9d41205c8f947e37751cd26e4812.1000x1000x1.jpg","name":"Spotify Sessions","url":"https://genius.com/albums/Sia/Spotify-sessions","datePublished":"2016-04-13","numTracks":6},{"@context":"http://schema.org","@type":"MusicAlbum","byArtist":{"@context":"http://schema.org","@type":"MusicGroup","name":"NOW That's What I Call Music!","url":"https://genius.com/artists/Now-thats-what-i-call-music","description":"“NOW That’s What I Call Music” is a series of compilation albums showcasing the latest in popular songs released by various artists.\n\nNOW distributes a different series of","image":"https://images.genius.com/2ad71039250d907203f1e0c96d3996e6.959x959x1.jpg"},"image":"https://images.genius.com/f4296a362acb022a36f5c5d13c77df5c.1000x1000x1.jpg","name":"NOW That’s What I Call Music! 88 [UK]","url":"https://genius.com/albums/Now-thats-what-i-call-music/Now-thats-what-i-call-music-88-uk","datePublished":"2014-07-21","numTracks":44},{"@context":"http://schema.org","@type":"MusicAlbum","byArtist":{"@context":"http://schema.org","@type":"MusicGroup","name":"Alligatoah","url":"https://genius.com/artists/Alligatoah","description":"Alligatoah, das ist eine HipHop-Band, die aus dem Rapper Kaliba 69 und dem Beatproduzenten DJ Deagle besteht. Ich habe diese beiden fiktiven Terroristen erfunden, weil ich nicht","image":"https://images.genius.com/ffb9b1ace1af8da503f1f64e84821b1b.960x960x1.png"},"image":"https://images.genius.com/940bb366aca1e1e4604f41441dfde361.1000x1000x1.jpg","name":"Fremde Zungen","url":"https://genius.com/albums/Alligatoah/Fremde-zungen","datePublished":"2018-09-14","numTracks":10},{"@context":"http://schema.org","@type":"MusicAlbum","byArtist":{"@context":"http://schema.org","@type":"MusicGroup","name":"Various Artists","url":"https://genius.com/artists/Various-artists","description":"Put this on the Primary Artist when you’re transcribing a song or album and it includes many artists – mainly for soundtracks.","image":"https://images.genius.com/399137c5d254397dc600fab5d0a978a8.594x594x1.png"},"image":"https://images.genius.com/7c1dd6a4ab303925cf769446b0acabfe.500x500x1.jpg","name":"MuchDance 2015","url":"https://genius.com/albums/Various-artists/Muchdance-2015","datePublished":"2014-11-04","numTracks":16}],"name":"Chandelier","url":"https://genius.com/Sia-c ...
#       </script>
# <routable-page>
# <ng-non-bindable>
# <div class="leaderboard_ad_container">
# </div>
# <div class="header_with_cover_art">
# <div class="header_with_cover_art-inner column_layout">
# <div class="column_layout-column_span column_layout-column_span--primary">
# <div class="header_with_cover_art-cover_art">
# <div class="cover_art">
# <img alt="Https%3a%2f%2fimages" class="cover_art-image" src="https://t2.genius.com/unsafe/220x220/https%3A%2F%2Fimages.genius.com%2F5bcfb76690b3fb068a317c76579b70b5.1000x1000x1.jpg" srcset="https://t2.genius.com/unsafe/440x440/https%3A%2F%2Fimages.genius.com%2F5bcfb76690b3fb068a317c76579b70b5.1000x1000x1.jpg 2x"/>
# </div>
# </div>
# <div class="header_with_cover_art-primary_info_container">
# <div class="header_with_cover_art-primary_info">
# <h1 class="header_with_cover_art-primary_info-title">Chandelier</h1>
# <h2>
# <a class="header_with_cover_art-primary_info-primary_artist" href="https://genius.com/artists/Sia">Sia</a>
# </h2>
# <h3>
# </h3>
# <h3>
# <div class="metadata_unit">
# <span class="metadata_unit-label">Produced by</span>
# <span class="metadata_unit-info">
# <a href="https://genius.com/artists/Greg-kurstin">Greg Kurstin</a> &amp; <a href="https://genius.com/artists/Jesse-shatkin">Jesse Shatkin</a>
# </span>
# </div>
# </h3>
# <h3>
# <div class="metadata_unit">
# <span class="metadata_unit-label">Album</span>
# <span class="metadata_unit-info"><a href="https://genius.com/albums/Sia/1000-forms-of-fear">1000 Forms of Fear</a></span>
# </div>
# </h3>
# </div>
# </div>
# </div>
# <div class="column_layout-column_span column_layout-column_span--secondary u-top_margin">
# </div>
# </div>
# </div>
# <div class="song_body column_layout" initial-content-for="song_body">
# <div class="column_layout-column_span column_layout-column_span--primary">
# <div class="song_body-lyrics">
# <h2 class="text_label text_label--gray text_label--x_small_text_size u-top_margin">Chandelier Lyrics</h2>
# <div initial-content-for="lyrics">
# <div class="lyrics">
# <!--sse-->
# <p><a annotation-fragment="2941072" class="referent" classification="verified" data-id="2941072" href="/Sia-chandelier-lyrics#note-2941072" image="false" ng-class="{
#           'referent--linked_to_preview': song_ctrl.referent_has_preview(fragment_id),
#           'referent--linked_to_preview_active': song_ctrl.highlight_preview_referent(fragment_element_id),
#           'referent--purple_indicator': song_ctrl.show_preview_referent_indicator(fragment_element_id)
#         }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="0" prevent-default-click="" verified-annotator-ids="656681">[Verse 1]</a><br/>
# <a annotation-fragment="2942509" class="referent" classification="accepted" data-id="2942509" href="/Sia-chandelier-lyrics#note-2942509" image="false" ng-class="{
#           'referent--linked_to_preview': song_ctrl.referent_has_preview(fragment_id),
#           'referent--linked_to_preview_active': song_ctrl.highlight_preview_referent(fragment_element_id),
#           'referent--purple_indicator': song_ctrl.show_preview_referent_indicator(fragment_element_id)
#         }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="2" prevent-default-click="">Party girls don't get hurt</a><br/>
# <a annotation-fragment="2941068" class="referent" classification="verified" data-id="2941068" href="/Sia-chandelier-lyrics#note-2941068" image="false" ng-class="{
#           'referent--linked_to_preview': song_ctrl.referent_has_preview(fragment_id),
#           'referent--linked_to_preview_active': song_ctrl.highlight_preview_referent(fragment_element_id),
#           'referent--purple_indicator': song_ctrl.show_preview_referent_indicator(fragment_element_id)
#         }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="0" prevent-default-click="" verified-annotator-ids="656681">Can't feel anything, when will I learn?<br/>
# I push it down, push it down</a><br/>
# <a annotation-fragment="2941037" class="referent" classification="verified" data-id="2941037" href="/Sia-chandelier-lyrics#note-2941037" image="false" ng-class="{
#           'referent--linked_to_preview': song_ctrl.referent_has_preview(fragment_id),
#           'referent--linked_to_preview_active': song_ctrl.highlight_preview_referent(fragment_element_id),
#           'referent--purple_indicator': song_ctrl.show_preview_referent_indicator(fragment_element_id)
#         }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="1" prevent-default-click="" verified-annotator-ids="656681">I'm the one "for a good time call"<br/>
# Phone's blowin' up, ringin' my doorbell<br/>
# I feel the love, feel the love</a><br/>
# <br/>
# [Pre-Chorus]<br/>
# <a annotation-fragment="2941040" class="referent" classification="verified" data-id="2941040" href="/Sia-chandelier-lyrics#note-2941040" image="false" ng-class="{
#           'referent--linked_to_preview': song_ctrl.referent_has_preview(fragment_id),
#           'referent--linked_to_preview_active': song_ctrl.highlight_preview_referent(fragment_element_id),
#           'referent--purple_indicator': song_ctrl.show_preview_referent_indicator(fragment_element_id)
#         }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="4" prevent-default-click="" verified-annotator-ids="656681">1 2 3, 1 2 3, drink<br/>
# 1 2 3, 1 2 3, drink<br/>
# 1 2 3, 1 2 3, drink</a><br/>
# <a annotation-fragment="2941043" class="referent" classification="verified" data-id="2941043" href="/Sia-chandelier-lyrics#note-2941043" image="false" ng-class="{
#           'referent--linked_to_preview': song_ctrl.referent_has_preview(fragment_id),
#           'referent--linked_to_preview_active': song_ctrl.highlight_preview_referent(fragment_element_id),
#           'referent--purple_indicator': song_ctrl.show_preview_referent_indicator(fragment_element_id)
#         }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="1" prevent-default-click="" verified-annotator-ids="656681">Throw 'em back till I lose count</a><br/>
# <br/>
# <a annotation-fragment="2941074" class="referent" classification="verified" data-id="2941074" href="/Sia-chandelier-lyrics#note-2941074" image="false" ng-class="{
#           'referent--linked_to_preview': song_ctrl.referent_has_preview(fragment_id),
#           'referent--linked_to_preview_active': song_ctrl.highlight_preview_referent(fragment_element_id),
#           'referent--purple_indicator': song_ctrl.show_preview_referent_indicator(fragment_element_id)
#         }" ng-click="open()" on-hover-with-no-digest="set_current_hover_and_digest(hover ? fragment_id : undefined)" pending-editorial-actions-count="0" prevent-default-click="" verified-annotator-ids="656681">[Chorus]</a><br/>
# ...
# </div>
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/Normandie-chandelier-lyrics">Chandelier by Normandie</a>
# </div>
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/Trent-harmon-chandelier-lyrics">Chandelier by Trent Harmon</a>
# </div>
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/Jordan-smith-chandelier-lyrics">​Chandelier by Jordan Smith</a>
# </div>
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/Anthem-lights-best-of-2014-problem-boom-clap-rude-am-i-wrong-all-about-that-bass-all-of-me-chandelier-blank-space-not-a-bad-thing-happy-lyrics">Best of 2014: Problem / Boom Clap / Rude / Am I Wrong / All About That Bass / All of Me / Chandelier / Blank Space / Not a Bad Thing / Happy by Anthem Lights</a>
# </div>
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/Gladys-knight-chandelier-lyrics">Chandelier by Gladys Knight</a>
# </div>
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/Kain-rivers-chandelier-lyrics">Chandelier by Kain Rivers</a>
# </div>
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/Dani-armstrong-chandelier-lyrics">Chandelier by Dani Armstrong (Ft. Scott Bradlee's Postmodern Jukebox)</a>
# </div>
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/Ali-brustofski-chandelier-lyrics">Chandelier by Ali Brustofski</a>
# </div>
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/The-girl-and-the-dreamcatcher-chandelier-lyrics">Chandelier by The Girl and the Dreamcatcher</a>
# </div>
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/Charlotte-awbery-chandelier-lyrics">Chandelier by Charlotte Awbery</a>
# </div>
# </span>
# </div>
# <div class="metadata_unit metadata_unit--table_row">
# <span class="metadata_unit-label">Remixed By</span>
# <span class="metadata_unit-info">
# <div class="u-x_small_bottom_margin">
# <a href="https://genius.com/Courtney-act-chandelier-diamonds-titanium-medley-annotated">Chandelier / Diamonds / Titanium (Medley) by Courtney Act</a>
# </div>
# </span>
# </div>
# </div>
# </div>
# <div initial-content-for="album">
# <div class="u-xx_large_vertical_margins">
# <div class="song_album u-bottom_margin">
# <a class="song_album-album_art" href="https://genius.com/albums/Sia/1000-forms-of-fear" title="1000 Forms of Fear">
# <img alt="Https%3a%2f%2fimages" src="https://t2.genius.com/unsafe/64x64/https%3A%2F%2Fimages.genius.com%2F0a2dfec3681e8b19da8c37dd7ecf193c.1000x1000x1.jpg" srcset="https://t2.genius.com/unsafe/128x128/https%3A%2F%2Fimages.genius.com%2F0a2dfec3681e8b19da8c37dd7ecf193c.1000x1000x1.jpg 2x"/>
# </a>
# <div class="song_album-info">
# <a class="song_album-info-title" href="https://genius.com/albums/Sia/1000-forms-of-fear" title="1000 Forms of Fear">
#       1000 Forms of Fear
#
#     </a>
# <a class="song_album-info-artist" href="https://genius.com/artists/Sia" title="1000 Forms of Fear">Sia</a>
# </div>
# </div>
# <div class="track_listing track_listing--columns">
# <div>
# <div class="track_listing-track track_listing-track--current">
# <span class="track_listing-track_number">1.  </span>
# <span>
#             Chandelier
#
#
#           </span>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">2.  </span>
# <a href="https://genius.com/Sia-big-girls-cry-lyrics" title="Big Girls Cry">
#             Big Girls Cry
#
#
#           </a>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">3.  </span>
# <a href="https://genius.com/Sia-burn-the-pages-lyrics" title="Burn the Pages">
#             Burn the Pages
#
#
#           </a>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">4.  </span>
# <a href="https://genius.com/Sia-eye-of-the-needle-lyrics" title="Eye of the Needle">
#             Eye of the Needle
#
#
#           </a>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">5.  </span>
# <a href="https://genius.com/Sia-hostage-lyrics" title="Hostage">
#             Hostage
#
#
#           </a>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">6.  </span>
# <a href="https://genius.com/Sia-straight-for-the-knife-lyrics" title="Straight for the Knife">
#             Straight for the Knife
#
#
#           </a>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">7.  </span>
# <a href="https://genius.com/Sia-fair-game-lyrics" title="Fair Game">
#             Fair Game
#
#
#           </a>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">8.  </span>
# <a href="https://genius.com/Sia-elastic-heart-lyrics" title="Elastic Heart">
#             Elastic Heart
#
#
#           </a>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">9.  </span>
# <a href="https://genius.com/Sia-free-the-animal-lyrics" title="Free the Animal">
#             Free the Animal
#
#
#           </a>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">10.  </span>
# <a href="https://genius.com/Sia-fire-meet-gasoline-lyrics" title="Fire Meet Gasoline">
#             Fire Meet Gasoline
#
#
#           </a>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">11.  </span>
# <a href="https://genius.com/Sia-cellophane-lyrics" title="Cellophane">
#             Cellophane
#
#
#           </a>
# </div>
# </div>
# <div>
# <div class="track_listing-track">
# <span class="track_listing-track_number">12.  </span>
# <a href="https://genius.com/Sia-dressed-in-black-lyrics" title="Dressed in Black">
#             Dressed in Black
#
#
#           </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <ul class="breadcrumbs">
# <li class="breadcrumb" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="https://genius.com/" itemprop="url">
# <span itemprop="title">Home</span>
# </a>
# </li>
# <li class="breadcrumb" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="https://genius.com/artists-index/s" itemprop="url">
# <span itemprop="title">S</span>
# </a>
# </li>
# <li class="breadcrumb" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="https://genius.com/artists/Sia" itemprop="url">
# <span itemprop="title">Sia</span>
# </a>
# </li>
# <li class="breadcrumb breadcrumb-current_page" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="https://genius.com/Sia-chandelier-lyrics" itemprop="url">
# <span itemprop="title">Chandelier Lyrics</span>
# </a>
# </li>
# </ul>
# </ng-non-bindable>
# </routable-page>
# <div class="page_footer page_footer--padding-for-sticky-player">
# <div class="footer">
# <div>
# <a href="/about">About Genius</a>
# <a href="/contributor_guidelines">Contributor Guidelines</a>
# <a href="/press" target="_blank">Press</a>
# <a href="mailto:inquiry@genius.com">Advertise</a>
# <a href="https://eventspace.genius.com/">Event Space</a>
# </div>
# <div>
# <a href="/static/privacy_policy" rel="nofollow" target="_blank">Privacy Policy</a>
# <a href="/static/licensing" rel="nofollow" target="_blank">Licensing</a>
# <a href="/jobs">Jobs</a>
# <a href="/developers">Developers</a>
# <a href="/static/terms" rel="nofollow" target="_blank">Terms of Use</a>
# <a href="/static/copyright" rel="nofollow" target="_blank">Copyright Policy</a>
# <a href="/feedback/new" rel="nofollow">Contact us</a>
# <a href="/static/ccpa" rel="nofollow" target="_blank">Do Not Sell My Personal Information</a>
# <a class="facebox" href="/login" rel="nofollow">Sign in</a>
# </div>
# <div>
# <span class="footer-copyright">© 2020 Genius Media Group Inc.</span>
# </div>
# </div>
# <div class="footer footer--secondary">
# <a class="footer-artist_links_label" href="/verified-artists">Verified Artists</a>
# <span class="footer-artist_links_label">All Artists:</span>
# <ul class="characters_index_list">
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/a">A</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/b">B</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/c">C</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/d">D</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/e">E</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/f">F</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/g">G</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/h">H</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/i">I</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/j">J</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/k">K</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/l">L</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/m">M</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/n">N</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/o">O</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/p">P</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/q">Q</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/r">R</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/s">S</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/t">T</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/u">U</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/v">V</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/w">W</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/x">X</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/y">Y</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/z">Z</a>
# </li>
# <li class="character_index_list-element">
# <a class="character_index_list-link" href="https://genius.com/artists-index/0">#</a>
# </li>
# </ul>
# </div>
# </div>
# <img height="0" src="https://loadus.exelator.com/load/?g=4&amp;j=0&amp;p=1183&amp;page-album_ids=%5B104614%5D%2C%5B362590%5D%2C%5B366657%5D%2C%5B461698%5D%2C%5B499393%5D&amp;page-album_in_top_10=false&amp;page-albums=1000+Forms+of+Fear%2CSpotify+Sessions%2CNOW+That%E2%80%99s+What+I+Call+Music%21+88+%5BUK%5D%2CFremde+Zungen%2CMuchDance+2015&amp;page-artist_ids=%5B16775%5D&amp;page-artist_in_top_10=false&amp;page-artists=Sia&amp;page-genre_ids=%5B73%5D%2C%5B435%5D%2C%5B352%5D%2C%5B72%5D%2C%5B16%5D&amp;page-genres=Ballad%2CReggae%2CR%26B+Genius%2CElectro-Pop%2CPop+Genius&amp;page-in_top_10=false&amp;page-new_release=false&amp;page-release_decade=2010&amp;page-release_month=201403&amp;page-release_year=2014&amp;page-type=song&amp;user_signed_in=false" style="display: block;" width="0"/>
# <script type="text/javascript">_qevents.push({ qacct: "p-f3CPQ6vHckedE"});</script>
# <noscript>
# <div style="display: none;">
# <img alt="Quantcast" height="1" src="http://pixel.quantserve.com/pixel/p-f3CPQ6vHckedE.gif" width="1">
# </img></div>
# </noscript>
# <script type="text/javascript">
#
#   var _sf_async_config={};
#
#   _sf_async_config.uid = 3877;
#   _sf_async_config.domain = 'genius.com';
#   _sf_async_config.title = 'Sia – Chandelier Lyrics | Genius Lyrics';
#   _sf_async_config.sections = 'songs,tag:r-b,tag:pop';
#   _sf_async_config.authors = 'Sia';
#
#   var _cbq = window._cbq || [];
#
#   (function(){
#     function loadChartbeat() {
#       window._sf_endpt=(new Date()).getTime();
#       var e = document.createElement('script');
#       e.setAttribute('language', 'javascript');
#       e.setAttribute('type', 'text/javascript');
#       e.setAttribute('src', 'https://static.chartbeat.com/js/chartbeat.js');
#       document.body.appendChild(e);
#     }
#     var oldonload = window.onload;
#     window.onload = (typeof window.onload != 'function') ?
#        loadChartbeat : function() { oldonload(); loadChartbeat(); };
#   })();
# </script>
# <!-- Begin comScore Tag -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "17151659" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=17151659&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '201983886890479');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=201983886890479&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script type="text/javascript">(function(e,b){if(!b.__SV){var a,f,i,g;window.mixpanel=b;a=e.createElement("script");a.type="text/javascript";a.async=!0;a.src=("https:"===e.location.protocol?"https:":"http:")+'//cdn.mxpnl.com/libs/mixpanel-2.2.min.js';f=e.getElementsByTagName("script")[0];f.parentNode.insertBefore(a,f);b._i=[];b.init=function(a,e,d){function f(b,h){var a=h.split(".");2==a.length&&(b=b[a[0]],h=a[1]);b[h]=function(){b.push([h].concat(Array.prototype.slice.call(arguments,0)))}}var c=b;"undefined"!==
# typeof d?c=b[d]=[]:d="mixpanel";c.people=c.people||[];c.toString=function(b){var a="mixpanel";"mixpanel"!==d&&(a+="."+d);b||(a+=" (stub)");return a};c.people.toString=function(){return c.toString(1)+".people (stub)"};i="disable track track_pageview track_links track_forms register register_once alias unregister identify name_tag set_config people.set people.set_once people.increment people.append people.track_charge people.clear_charges people.delete_user".split(" ");for(g=0;g<i.length;g++)f(c,i[g]);
# b._i.push([a,e,d])};b.__SV=1.2}})(document,window.mixpanel||[]);
# mixpanel.init('77967c52dc38186cc1aadebdd19e2a82');</script>
# </body>
# </html>
